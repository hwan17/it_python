# %%
import seaborn as sns
import pandas as pd
df1 = sns.load_dataset('titanic')
df2 = pd.read_csv('d:\\data\\csv\\train.csv')

# print(len(df1))
# print(len(df2))
# Out:
# 891
# 891

# %%
df1.age
df2.Age
pd.concat([df1[['age']],df2[['Age']]], axis = 1)
# Out:
#       age   Age
# 0    22.0  22.0
# 1    38.0  38.0
# 2    26.0  26.0
# 3    35.0  35.0
# 4    35.0  35.0
# ..    ...   ...
# 886  27.0  27.0
# 887  19.0  19.0
# 888   NaN   NaN
# 889  26.0  26.0
# 890  32.0  32.0
#
# [891 rows x 2 columns]

# %%
import pandas as pd

# 데이터프레임 만들기

df1 = pd.DataFrame(
    {
        'a': ['a0', 'a1', 'a2', 'a3'],
        'b': ['b0', 'b1', 'b2', 'b3'],
        'c': ['c0', 'c1', 'c2', 'c3']
    },
    index=[0, 1, 2, 3])

df2 = pd.DataFrame(
    {
        'a': ['a2', 'a3', 'a4', 'a5'],
        'b': ['b2', 'b3', 'b4', 'b5'],
        'c': ['c2', 'c3', 'c4', 'c5'],
        'd': ['d2', 'd3', 'd4', 'd5']
    },
    index=[2, 3, 4, 5])

print(df1, '\n')
print(df2, '\n')

pd.concat([df1,df2], axis = 1 , join = 'inner')
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
#
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5
#     a   b   c   a   b   c   d
# 2  a2  b2  c2  a2  b2  c2  d2
# 3  a3  b3  c3  a3  b3  c3  d3

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')
dept = pd.read_csv('d:\\data\\csv\\dept3cn.csv')


pd.concat([emp,dept], axis = 1 ,join = 'outer')
# Out:
#     empno   ename        job     mgr         hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN      20
# ...

# %%
pd.merge(emp,dept,how='inner',on='deptno')[['ename','loc']]
# Out:
#      ename       loc
# 0     KING  NEW YORK
# 1    CLARK  NEW YORK
# 2   MILLER  NEW YORK
# 3    BLAKE   CHICAGO
# 4   MARTIN   CHICAGO
# 5    ALLEN   CHICAGO
# 6   TURNER   CHICAGO
# 7    JAMES   CHICAGO
# 8     WARD   CHICAGO
# 9    JONES    DALLAS
# 10    FORD    DALLAS
# 11   SMITH    DALLAS
# 12   SCOTT    DALLAS
# 13   ADAMS    DALLAS

# %%
pd.merge(emp,dept,how='right',on='deptno')[['ename','loc']]
# Out:
#      ename       loc
# 0     KING  NEW YORK
# 1    CLARK  NEW YORK
# 2   MILLER  NEW YORK
# 3    BLAKE   CHICAGO
# 4   MARTIN   CHICAGO
# 5    ALLEN   CHICAGO
# 6   TURNER   CHICAGO
# 7    JAMES   CHICAGO
# 8     WARD   CHICAGO
# 9    JONES    DALLAS
# 10    FORD    DALLAS
# 11   SMITH    DALLAS
# 12   SCOTT    DALLAS
# 13   ADAMS    DALLAS
# 14     NaN    BOSTON

# %%
df1 = pd.read_excel('d:\\data\\csv\\실습파일\\stock price.xlsx')
df2 = pd.read_excel('d:\\data\\csv\\실습파일\\stock valuation.xlsx')

pd.merge(df1,df2, how = 'outer', on = 'id')
# Out:
#         id stock_name          value     price       name           eps  \
# 0   128940       한미약품   59385.666667  421000.0        NaN           NaN
# 1   130960     CJ E&M   58540.666667   98900.0     CJ E&M   6301.333333
# 2   138250      엔에스쇼핑   14558.666667   13200.0        NaN           NaN
# 3   139480        이마트  239230.833333  254500.0        이마트  18268.166667
# 4   142280     녹십자엠에스     468.833333   10200.0        NaN           NaN
# 5   145990        삼양사   82750.000000   82000.0        삼양사   5741.000000
# 6   185750        종근당   40293.666667  100500.0        종근당   3990.333333
# 7   192400      쿠쿠홀딩스  179204.666667  177500.0        NaN           NaN
# 8   199800         툴젠   -2514.333333  115400.0        NaN           NaN
# 9   204210     모두투어리츠    3093.333333    3475.0     모두투어리츠     85.166667
# 10  136480        NaN            NaN       NaN         하림    274.166667
# 11  138040        NaN            NaN       NaN    메리츠금융지주   2122.333333
# ...

# %%
df1 = pd.read_excel('d:\\data\\csv\\실습파일\\stock price.xlsx')
df2 = pd.read_excel('d:\\data\\csv\\실습파일\\stock valuation.xlsx')

df3 = pd.merge(df1,df2, how = 'outer', on = 'id')

len(df3[df3.price < 50000])

(df3.price < 50000).sum()
# Out:
# 3

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv', index_col = 'deptno')
dept = pd.read_csv('d:\\data\\csv\\dept3cn.csv', index_col = 'deptno')

emp.join(dept, how = 'right')
# Out:
#          empno   ename        job     mgr         hiredate     sal    comm  \
# deptno
# 10      7839.0    KING  PRESIDENT     NaN  1981-11-17 0:00  5000.0     NaN
# 10      7782.0   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450.0     NaN
# 10      7934.0  MILLER      CLERK  7782.0  1982-01-11 0:00  1300.0     NaN
# 20      7566.0   JONES    MANAGER  7839.0  1981-04-01 0:00  2975.0     NaN
# 20      7902.0    FORD    ANALYST  7566.0  1981-12-11 0:00  3000.0     NaN
# 20      7369.0   SMITH      CLERK  7902.0  1980-12-09 0:00   800.0     NaN
# 20      7788.0   SCOTT    ANALYST  7566.0  1982-12-22 0:00  3000.0     NaN
# 20      7876.0   ADAMS      CLERK  7788.0  1983-01-15 0:00  1100.0     NaN
# 30      7698.0   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850.0     NaN
# 30      7654.0  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250.0  1400.0
# 30      7499.0   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600.0   300.0
# ...

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv', index_col = 'deptno')
dept = pd.read_csv('d:\\data\\csv\\dept3cn.csv', index_col = 'deptno')

emp.join(dept, how = 'outer')
# Out:
#          empno   ename        job     mgr         hiredate     sal    comm  \
# deptno
# 10      7839.0    KING  PRESIDENT     NaN  1981-11-17 0:00  5000.0     NaN
# 10      7782.0   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450.0     NaN
# 10      7934.0  MILLER      CLERK  7782.0  1982-01-11 0:00  1300.0     NaN
# 20      7566.0   JONES    MANAGER  7839.0  1981-04-01 0:00  2975.0     NaN
# 20      7902.0    FORD    ANALYST  7566.0  1981-12-11 0:00  3000.0     NaN
# 20      7369.0   SMITH      CLERK  7902.0  1980-12-09 0:00   800.0     NaN
# 20      7788.0   SCOTT    ANALYST  7566.0  1982-12-22 0:00  3000.0     NaN
# 20      7876.0   ADAMS      CLERK  7788.0  1983-01-15 0:00  1100.0     NaN
# 30      7698.0   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850.0     NaN
# 30      7654.0  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250.0  1400.0
# 30      7499.0   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600.0   300.0
# ...

# %%
df1 = sns.load_dataset('titanic')
df = df1.loc[:,['age','sex','class','fare','survived']]

grouped = df.groupby('class')
for key,group in grouped:
    print('key:', key)
    print('number:',len(group))
    print(group.head())
    print('\n')



#df1.groupby("class")['survived'].mean()

average = grouped.mean()
average
# Out:
# key: First
# number: 216
#      age     sex  class     fare  survived
# 1   38.0  female  First  71.2833         1
# 3   35.0  female  First  53.1000         1
# 6   54.0    male  First  51.8625         0
# 11  58.0  female  First  26.5500         1
# 23  28.0    male  First  35.5000         1
#
#
# key: Second
# number: 184
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 17   NaN    male  Second  13.0000         1
# 20  35.0    male  Second  26.0000         0
# 21  34.0    male  Second  13.0000         1
#
#
# key: Third
# number: 491
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# ...

# %%
grouped= emp.groupby('deptno')
grouped.mean().sort_values('sal', ascending= False)
# Out:
#               empno     mgr          sal   comm
# deptno
# 10      7851.666667  7810.5  2916.666667    NaN
# 20      7700.200000  7732.2  2175.000000    NaN
# 30      7686.000000  7721.5  1566.666667  550.0

# %%
emp.groupby('deptno')[['sal']].mean()
# Out:
#                 sal
# deptno
# 10      2916.666667
# 20      2175.000000
# 30      1566.666667

# %%
df1 = sns.load_dataset('titanic')
df = df1.loc[:,['age','sex','class','fare','survived']]

grouped = df.groupby(['class','sex'])
for key,group in grouped:
    print('key:', key)
    print('number:',len(group))
    print(group.head())
    print('\n')
    

average = grouped.mean()
average
# Out:
# key: ('First', 'female')
# number: 94
#      age     sex  class      fare  survived
# 1   38.0  female  First   71.2833         1
# 3   35.0  female  First   53.1000         1
# 11  58.0  female  First   26.5500         1
# 31   NaN  female  First  146.5208         1
# 52  49.0  female  First   76.7292         1
#
#
# key: ('First', 'male')
# number: 122
#      age   sex  class      fare  survived
# 6   54.0  male  First   51.8625         0
# 23  28.0  male  First   35.5000         1
# 27  19.0  male  First  263.0000         0
# 30  40.0  male  First   27.7208         0
# 34  28.0  male  First   82.1708         0
#
#
# key: ('Second', 'female')
# number: 76
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 41  27.0  female  Second  21.0000         0
# 43   3.0  female  Second  41.5792         1
# 53  29.0  female  Second  26.0000         1
#
#
# key: ('Second', 'male')
# number: 108
# ...

# %%
emp.groupby(['deptno','job'])['sal'].mean()
# Out:
# deptno  job
# 10      CLERK        1300
#         MANAGER      2450
#         PRESIDENT    5000
# 20      ANALYST      3000
#         CLERK         950
#         MANAGER      2975
# 30      CLERK         950
#         MANAGER      2850
#         SALESMAN     1400
# Name: sal, dtype: int64

# %%
grouped= emp.groupby(['deptno','job'])
grouped.mean()
# Out:
#                    empno     mgr     sal   comm
# deptno job
# 10     CLERK      7934.0  7782.0  1300.0    NaN
#        MANAGER    7782.0  7839.0  2450.0    NaN
#        PRESIDENT  7839.0     NaN  5000.0    NaN
# 20     ANALYST    7845.0  7566.0  3000.0    NaN
#        CLERK      7622.5  7845.0   950.0    NaN
#        MANAGER    7566.0  7839.0  2975.0    NaN
# 30     CLERK      7900.0  7698.0   950.0    NaN
#        MANAGER    7698.0  7839.0  2850.0    NaN
#        SALESMAN   7629.5  7698.0  1400.0  550.0

# %%
df1 = sns.load_dataset('titanic')
df = df1.loc[:,['class','fare']]

grouped = df.groupby(['class'])

std = grouped.std()
std
# Out:
#              fare
# class
# First   78.380373
# Second  13.417399
# Third   11.778142

# %%
df1[df1['class']=='First'][['class','fare']].sort_values('fare',ascending = False)
# Out:
#      class      fare
# 258  First  512.3292
# 737  First  512.3292
# 679  First  512.3292
# 88   First  263.0000
# 27   First  263.0000
# ..     ...       ...
# 815  First    0.0000
# 806  First    0.0000
# 633  First    0.0000
# 822  First    0.0000
# 263  First    0.0000
#
# [216 rows x 2 columns]

# %%
grouped = emp.groupby('deptno')
grouped['sal'].agg(sum)
# Out:
# deptno
# 10     8750
# 20    10875
# 30     9400
# Name: sal, dtype: int64

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')

df = emp.loc[:,['sal','deptno']]
df
grouped = df.groupby(['deptno'])
grouped.agg(sum)
# Out:
#           sal
# deptno
# 10       8750
# 20      10875
# 30       9400

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')

df = emp.loc[:,['sal','deptno']]
df
grouped = df.groupby(['deptno'])
grouped.agg([min,max])
# Out:
#          sal
#          min   max
# deptno
# 10      1300  5000
# 20       800  3000
# 30       950  2850

# %%
df1 = pd.read_csv('d:\\data\\csv\\train.csv')
df = df1.loc[:,['Fare','Pclass']]
grouped = df.groupby(['Pclass'])
grouped.agg([min,max])
# Out:
#        Fare
#         min       max
# Pclass
# 1       0.0  512.3292
# 2       0.0   73.5000
# 3       0.0   69.5500

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')

df = emp.loc[:,['ename','sal','job','deptno']]
df
grouped = df.groupby(['deptno'])
grouped.filter(lambda x:x.sal.mean() < 2000)
# Out:
#     ename   sal       job  deptno
# 1   BLAKE  2850   MANAGER      30
# 4  MARTIN  1250  SALESMAN      30
# 5   ALLEN  1600  SALESMAN      30
# 6  TURNER  1500  SALESMAN      30
# 7   JAMES   950     CLERK      30
# 8    WARD  1250  SALESMAN      30

# %%
emp[['ename','sal','job','deptno']].groupby('deptno').filter(lambda x:x.sal.mean()<2000)
# Out:
#     ename   sal       job  deptno
# 1   BLAKE  2850   MANAGER      30
# 4  MARTIN  1250  SALESMAN      30
# 5   ALLEN  1600  SALESMAN      30
# 6  TURNER  1500  SALESMAN      30
# 7   JAMES   950     CLERK      30
# 8    WARD  1250  SALESMAN      30

# %%
emp[['ename','sal','job','deptno']].groupby('deptno').sal.mean()
# Out:
# deptno
# 10    2916.666667
# 20    2175.000000
# 30    1566.666667
# Name: sal, dtype: float64

# %%
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = tit.loc[:,['Name','Survived','Age','Pclass','Fare']]
grouped = df.groupby('Pclass')
result = grouped.apply(lambda x:x.describe())
result
# Out:
#                 Survived         Age  Pclass        Fare
# Pclass
# 1      count  216.000000  186.000000   216.0  216.000000
#        mean     0.629630   38.233441     1.0   84.154687
#        std      0.484026   14.802856     0.0   78.380373
#        min      0.000000    0.920000     1.0    0.000000
#        25%      0.000000   27.000000     1.0   30.923950
#        50%      1.000000   37.000000     1.0   60.287500
#        75%      1.000000   49.000000     1.0   93.500000
#        max      1.000000   80.000000     1.0  512.329200
# 2      count  184.000000  173.000000   184.0  184.000000
#        mean     0.472826   29.877630     2.0   20.662183
#        std      0.500623   14.001077     0.0   13.417399
#        min      0.000000    0.670000     2.0    0.000000
#        25%      0.000000   23.000000     2.0   13.000000
#        50%      0.000000   29.000000     2.0   14.250000
#        75%      1.000000   36.000000     2.0   26.000000
# ...

# %%
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = tit.loc[:,['Name','Survived','Age','Pclass','Fare']]
grouped = df.groupby('Pclass')
def zscore(x):
    return ((x-x.mean())/x.std() )
result = grouped.Age.apply(zscore )
result.describe()
# Out:
# count    7.140000e+02
# mean    -7.945714e-17
# std      9.985965e-01
# min     -2.520692e+00
# 25%     -5.714600e-01
# 50%     -6.268304e-02
# 75%      5.922208e-01
# max      3.910190e+00
# Name: Age, dtype: float64

# %%
type(df.Name[0])==str
# Out:
# True

# %%
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = tit.loc[:,['Name','Survived','Age','Pclass','Fare']]
grouped = df.groupby('Pclass')
def mm(x):
    return ((x-x.min())/(x.max()-x.min()) )
result = grouped.Fare.apply(mm )
result

# %%
tit.Fare.pipe(mm)
# Out:
# 0      0.014151
# 1      0.139136
# 2      0.015469
# 3      0.103644
# 4      0.015713
#          ...
# 886    0.025374
# 887    0.058556
# 888    0.045771
# 889    0.058556
# 890    0.015127
# Name: Fare, Length: 891, dtype: float64

# %%
tit.Fare.apply(mm)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-194-fdb1fe2fb73c> in <module>
# ----> 1 tit.Fare.apply(mm)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-182-a3dbb47a4cbb> in mm(x)
#       3 grouped = df.groupby('Pclass')
#       4 def mm(x):
# ----> 5     return ((x-x.min())/(x.max()-x.min()) )
#       6 result = grouped.Fare.apply(mm )
#       7 result
#
# AttributeError: 'float' object has no attribute 'min'

# %%
tit.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = tit.loc[:,['Name','Survived','Sex','Age','Pclass','Fare']]
grouped = df.groupby(['Pclass','Sex'])
gdf = grouped.mean()
gdf
# Out:
#                Survived        Age        Fare
# Pclass Sex
# 1      female  0.968085  34.611765  106.125798
#        male    0.368852  41.281386   67.226127
# 2      female  0.921053  28.722973   21.970121
#        male    0.157407  30.740707   19.741782
# 3      female  0.500000  21.750000   16.118810
#        male    0.135447  26.507589   12.661633

# %%
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = tit.loc[:,['Name','Survived','Sex','Age','Pclass','Fare']]
grouped = df.groupby(['Pclass','Sex'])
gdf = grouped.mean()
#gdf.loc[1].loc['female']
gdf.iloc[4]
# Out:
# Survived     0.50000
# Age         21.75000
# Fare        16.11881
# Name: (3, female), dtype: float64

# %% [markdown]
# 타이타닉 knn

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')
pd.set_option('display.max_columns',15)
df.shape
# Out:
# (891, 15)

# %%
import pandas as pd
import seaborn as sns
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = sns.load_dataset('titanic')
df = pd.concat([df,tit[["Name"]]],axis=1)
df
#tit[["Name"]]
df.info()
df.isnull().sum()
# # deck의 결측치는 전체 891개 중 688개 이므로 삭제
# # embark 와 embark_town은 같은 데이터 이므로 삭제
rdf = df.drop(['deck','embark_town'],axis = 1)
rdf.columns.values
# # # age의 결측치 177개  행 삭제

rdf['title']=rdf.Name.str.split('[.,]').str[1].str.strip()
df2 = rdf.groupby('title')['age'].mean().round(1).reset_index()
df3 = pd.merge(rdf,df2,on='title')
df3.age_x.fillna(df3.age_y,inplace=True)
df3
# rdf = rdf.fillna( subset=['age'], how='any',axis=0)
# len(rdf)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  Name         891 non-null    object
# dtypes: bool(2), category(2), float64(2), int64(4), object(6)
# memory usage: 87.6+ KB
# ...

# %%
type(tit1.age[0])

# %%
#3.1 머신러닝 학습에 필요한 컬럼을 선택(feature selection)
#ndf = rdf[[ 'survived','pclass','sex','age','sibsp','parch','embarked']]
ndf = df3[[ 'survived','pclass','sex','age_x','sibsp','parch','embarked']]

ndf.head()
# sex, embarked를 제외하고 숫자
#3.2 범주형 데이터를 숫자로 변한(onehot encoding)
gender = pd.get_dummies(ndf['sex'])
ndf = pd.concat([ndf,gender], axis = 1)
onehot_embarked = pd.get_dummies(ndf['embarked'],prefix = 'town')
# 설명 : prefic=town이라고 해야 컬럼안의 도시명으로 컬럼명이 만들어짐
ndf = pd.concat([ndf,onehot_embarked],axis=1 )
ndf
# 3.3 범주형 컬럼 drop
ndf.drop(['sex','embarked'], axis = 1, inplace=True)
ndf
# Out:
#      survived  pclass  age_x  sibsp  parch  female  male  town_C  town_Q  \
# 0           0       3   22.0      1      0       0     1       0       0
# 1           0       3   35.0      0      0       0     1       0       0
# 2           0       3   32.4      0      0       0     1       0       1
# 3           0       1   54.0      0      0       0     1       0       0
# 4           0       3   20.0      0      0       0     1       0       0
# ..        ...     ...    ...    ...    ...     ...   ...     ...     ...
# 886         1       1   56.0      0      0       0     1       1       0
# 887         0       1   60.0      0      0       0     1       0       0
# 888         0       1   70.0      1      1       0     1       0       0
# 889         1       1   33.0      0      0       1     0       0       0
# 890         0       1   38.0      0      0       0     1       0       0
#
#      town_S
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1
# ...

# %%
# 독립변수와 종속변수로 분리한다.
x = ndf[['pclass','age_x','sibsp','parch','female','male','town_C','town_Q','town_S']]
y = ndf[['survived']]

# %%
from sklearn import preprocessing

x = preprocessing.StandardScaler().fit(x).transform(x)
x
# Out:
# array([[ 0.82737724, -0.5847987 ,  0.43279337, ..., -0.48204268,
#         -0.30756234,  0.61930636],
#        [ 0.82737724,  0.39487426, -0.4745452 , ..., -0.48204268,
#         -0.30756234,  0.61930636],
#        [ 0.82737724,  0.19893967, -0.4745452 , ..., -0.48204268,
#          3.25137334, -1.61470971],
#        ...,
#        [-1.56610693,  3.03245529,  0.43279337, ..., -0.48204268,
#         -0.30756234,  0.61930636],
#        [-1.56610693,  0.24415534, -0.4745452 , ..., -0.48204268,
#         -0.30756234,  0.61930636],
#        [-1.56610693,  0.62095263, -0.4745452 , ..., -0.48204268,
#         -0.30756234,  0.61930636]])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size =0.3, random_state=10)

# %%
y_train.shape
# Out:
# (499, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train,y_train)
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   after removing the cwd from sys.path.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_hat = knn.predict(x_test)

# %%
from sklearn import metrics

knn_matrix = metrics.confusion_matrix(y_test, y_hat)
knn_matrix
# Out:
# array([[138,  25],
#        [ 33,  72]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_hat)
print(accuracy)
# Out:
# 0.7835820895522388

# %%
import pandas as pd
import seaborn as sns
tit = pd.read_csv('d:\\data\\csv\\train.csv')
df = sns.load_dataset('titanic')
pd.merge(tit,df,left_on='Age',right_on='age',how='inner')
# Out:
#        PassengerId  Survived  Pclass                             Name   Sex  \
# 0                1         0       3          Braund, Mr. Owen Harris  male
# 1                1         0       3          Braund, Mr. Owen Harris  male
# 2                1         0       3          Braund, Mr. Owen Harris  male
# 3                1         0       3          Braund, Mr. Owen Harris  male
# 4                1         0       3          Braund, Mr. Owen Harris  male
# ...            ...       ...     ...                              ...   ...
# 42516          815         0       3       Tomlin, Mr. Ernest Portage  male
# 42517          815         0       3       Tomlin, Mr. Ernest Portage  male
# 42518          804         1       3  Thomas, Master. Assad Alexander  male
# 42519          844         0       3       Lemberopolous, Mr. Peter L  male
# 42520          852         0       3              Svensson, Mr. Johan  male
#
# ...

# %%
tit = pd.read_csv('d:\\data\\csv\\train.csv')

tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
