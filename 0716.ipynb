# %%
import pandas as pd
df = pd.DataFrame( {'c1':['a','a','a','b','b'], 'c2':[1,1,1,2,2], 'c3':[1,1,2,2,2] } )
print(df)
df.duplicated()
# Out:
#   c1  c2  c3
# 0  a   1   1
# 1  a   1   1
# 2  a   1   2
# 3  b   2   2
# 4  b   2   2
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
import pandas as pd
df = pd.DataFrame( {'c1':['a','a','a','b','b'], 'c2':[1,1,1,2,2], 'c3':[1,1,2,2,2] } )
#print(df)
df.c2.duplicated().sum()
# Out:
# 3

# %%
import pandas as pd
df = pd.DataFrame( {'c1':['a','a','a','b','b'], 'c2':[1,1,1,2,2], 'c3':[1,1,2,2,2] } )
df.drop_duplicates()
# Out:
#   c1  c2  c3
# 0  a   1   1
# 2  a   1   2
# 3  b   2   2

# %%
import seaborn as sns
tit = sns.load_dataset('titanic')
tit.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
import pandas as pd
df = pd.read_csv('d:\\data\\csv\\실습파일\\auto-mpg.csv', header=None)
df.columns= ['mpg','cylinders','displacement','horsepower','weight','acceleration','medel year','origin','name']

print(df.head(3))
#df
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  medel year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %%
mpg_to_kpl = 1.60934/3.87541

# %%
df['kpl']=round(df['mpg']*mpg_to_kpl,2)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      medel year  origin                       name    kpl
# 0            70       1  chevrolet chevelle malibu   7.47
# ...

# %%
df.horsepower.unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
import numpy as np
df.horsepower.replace("?",np.nan, inplace=True)

# %%
df.dropna(axis=0)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      medel year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.dropna( subset=['horsepower'], axis=0, inplace=True)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      medel year  origin                       name    kpl
# 0            70       1  chevrolet chevelle malibu   7.47
# ...

# %%
df.dtypes
# Out:
# mpg              float64
# cylinders          int64
# displacement     float64
# horsepower       float64
# weight           float64
# acceleration     float64
# medel year         int64
# origin             int64
# name              object
# kpl              float64
# hp_bin          category
# 고출력                uint8
# hf_n             float64
# dtype: object

# %%
df.horsepower = df.horsepower.astype(float)

# %%
count, bin_dividers = np.histogram(df.horsepower,bins=3)
print(count) # 구간에 속하는 값의 개수
bin_dividers # 경계값 리스트
bin_names = ['저출력','보통출력','고출력']
df['hp_bin']= pd.cut(x = df.horsepower, bins=bin_dividers, labels=bin_names)
df
# Out:
# [257 103  32]
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      medel year  origin                       name    kpl hp_bin
# ...

# %%
df.horsepower.max()
# Out:
# 230.0

# %%
emp = pd.read_csv("d:\\data\\csv\\empcn.csv")
count, bin_dividers = np.histogram(emp.sal,bins=3)
bin_names = ['저소득','중간소득','고소득']
emp['sal_bin']= pd.cut(x = emp.sal, bins=bin_dividers, labels=bin_names)
emp
bin_dividers
# Out:
# array([ 800., 2200., 3600., 5000.])

# %%
horsepower_dummies = pd.get_dummies( df.hp_bin )
horsepower_dummies.head()
# Out:
#    저출력  보통출력  고출력
# 0    0     1    0
# 1    0     1    0
# 2    0     1    0
# 3    0     1    0
# 4    0     1    0

# %%
sal_dummies = pd.get_dummies(emp.sal_bin)
sal_dummies
# Out:
#     저소득  중간소득  고소득
# 0     0     0    1
# 1     0     1    0
# 2     0     1    0
# 3     0     1    0
# 4     1     0    0
# 5     1     0    0
# 6     1     0    0
# 7     1     0    0
# 8     1     0    0
# 9     0     1    0
# 10    0     0    0
# 11    0     1    0
# 12    1     0    0
# 13    1     0    0

# %%
emp['고소득'] = sal_dummies.고소득
emp
# Out:
#     empno   ename        job     mgr         hiredate   sal    comm  deptno  \
# 0    7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN      30
# 2    7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN      10
# 3    7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0      30
# 5    7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0      30
# 6    7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0      30
# 7    7900   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN      30
# 8    7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0      30
# 9    7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN      20
# 10   7369   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN      20
# ...

# %%
df['고출력'] =horsepower_dummies.고출력
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      medel year  origin                       name    kpl hp_bin  고출력
# ...

# %%
horsepower_dummies.고출력
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 393    0
# 394    0
# 395    0
# 396    0
# 397    0
# Name: 고출력, Length: 392, dtype: uint8

# %%
maxhp = df.horsepower.max()
minhp = df.horsepower.min()

# %%
df['hf_n'] = (df.horsepower - minhp ) / (maxhp-minhp)

# %%
df.hf_n.describe()
# Out:
# count    392.000000
# mean       0.317768
# std        0.209191
# min        0.000000
# 25%        0.157609
# 50%        0.258152
# 75%        0.434783
# max        1.000000
# Name: hf_n, dtype: float64

# %%
from sklearn import preprocessing
hp_s = preprocessing.StandardScaler().fit(df[['horsepower']]).transform(df[['horsepower']])
df['hp_s'] = hp_s

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      medel year  origin                       name    kpl hp_bin  고출력  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib 패키지 한글 설정 시작
from matplotlib import rc
rc('font', family='Malgun Gothic')
#matplotlib 패키지 한글 설정 끝

#1. 데이터 로드

df = pd.read_csv('https://raw.githubusercontent.com/ivanarielcaceres/timeseries-lstm-keras/master/data/international-airline-passengers.csv')
#2. 데이터 분석

print(df.head())
print(df.tail())
print(df.info())

#3. 시각화 하기 

import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (30,10) # (가로, 세로)

plt.rcParams.update({'font.size': 9}) # 글자 크기
sns.lineplot(x='Month', y='Passengers', data=df)
plt.show()

#4.  결측치를 제거합니다.

import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

df = pd.read_csv('https://raw.githubusercontent.com/ivanarielcaceres/timeseries-lstm-keras/master/data/international-airline-passengers.csv')

print(df)
df = df.dropna()
print(df)

#5. 년도와 달에 대한 컬럼을 만들어서 행 인덱스로 지정합니다. 

df['Month'] = pd.to_datetime(df.Month, format='%Y-%m')
df = df.set_index('Month')
df.head()

#6. 모델을 생성합니다.

import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

order = (2, 1, 2)
#model = ARIMA(df, order, freq='D')
model = ARIMA(df, order)
fit = model.fit()

#print(fit.summary())

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib 패키지 한글 설정 시작
from matplotlib import rc
rc('font', family='Malgun Gothic') 
#matplotlib 패키지 한글 설정 끝

#1. 데이터 로드

#df = pd.read_csv('https://raw.githubusercontent.com/ivanarielcaceres/timeseries-lstm-keras/master/data/international-airline-passengers.csv')

#2. 데이터 분석

print(df.head())
print(df.tail())
print(df.info())

#3. 시각화 하기 

import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (30,10) # (가로, 세로)

plt.rcParams.update({'font.size': 9}) # 글자 크기
sns.lineplot(x='Month', y='Passengers', data=df)
plt.show()

#4.  결측치를 제거합니다.

import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

df = pd.read_csv('https://raw.githubusercontent.com/ivanarielcaceres/timeseries-lstm-keras/master/data/international-airline-passengers.csv')

print(df)
df = df.dropna()
print(df)

#5. 년도와 달에 대한 컬럼을 만들어서 행 인덱스로 지정합니다. 

df['Month'] = pd.to_datetime(df.Month, format='%Y-%m')
df = df.set_index('Month')
df.head()

#6. 모델을 생성합니다.

import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

order = (2, 1, 2)
#model = ARIMA(df, order, freq='D')
model = ARIMA(df, order)
fit = model.fit()

#print(fit.summary())

#7. 예측을 합니다. 
 
preds = fit.predict(1, 30, typ='levels')
print(preds)

#8. 기간을 주고 예측합니다.

#preds = fit.predict("2001-11-02", "2001-12-15", typ='levels')
#print(preds)
# Out:
#   File "<ipython-input-113-2b91c0cee77c>", line 62
#     rc('font', family='Malgun Gothic')
#                                       ^
# SyntaxError: invalid character in identifier

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ivanarielcaceres/timeseries-lstm-keras/master/data/international-airline-passengers.csv')
df.shape
# Out:
# (146, 2)

# %%
print(df.head())
print(df.tail())
print(df.info())
# Out:
#      Month  Passengers
# 0  1949-01       112.0
# 1  1949-02       118.0
# 2  1949-03       132.0
# 3  1949-04       129.0
# 4  1949-05       121.0
#                                                  Month  Passengers
# 141                                            1960-10       461.0
# 142                                            1960-11       390.0
# 143                                            1960-12       432.0
# 144                                                NaN         NaN
# 145  International airline passengers: monthly tota...         NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       145 non-null    object
#  1   Passengers  144 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.4+ KB
# None

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (30,10) # (가로, 세로)

plt.rcParams.update({'font.size': 9}) # 글자 크기
sns.lineplot(x='Month', y='Passengers', data=df)
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

df = pd.read_csv('https://raw.githubusercontent.com/ivanarielcaceres/timeseries-lstm-keras/master/data/international-airline-passengers.csv')

print(df)
df = df.dropna()
print(df)
# Out:
#                                                  Month  Passengers
# 0                                              1949-01       112.0
# 1                                              1949-02       118.0
# 2                                              1949-03       132.0
# 3                                              1949-04       129.0
# 4                                              1949-05       121.0
# ..                                                 ...         ...
# 141                                            1960-10       461.0
# 142                                            1960-11       390.0
# 143                                            1960-12       432.0
# 144                                                NaN         NaN
# 145  International airline passengers: monthly tota...         NaN
#
# [146 rows x 2 columns]
#        Month  Passengers
# 0    1949-01       112.0
# 1    1949-02       118.0
# 2    1949-03       132.0
# 3    1949-04       129.0
# ...

# %%
df['Month'] = pd.to_datetime(df.Month, format='%Y-%m') #날짜형으로 변환
df = df.set_index('Month') # 행인덱스로 지정
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01       112.0
# 1949-02-01       118.0
# 1949-03-01       132.0
# 1949-04-01       129.0
# 1949-05-01       121.0

# %%
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

order = (2, 1, 2)
#model = ARIMA(df, order, freq='D')
model = ARIMA(df, order)
fit = model.fit()

print(fit.summary())
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\knit\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ...
# Dep. Variable:           D.Passengers   No. Observations:                  143
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                -666.022
# Method:                       css-mle   S.D. of innovations             24.713
# Date:                Thu, 16 Jul 2020   AIC                           1344.043
# Time:                        14:34:04   BIC                           1361.820
# Sample:                    02-01-1949   HQIC                          1351.267
#                          - 12-01-1960
# ...

# %%
preds = fit.predict(1, 3000, typ='levels')
print(preds)
# Out:
# 1949-02-01     114.530750
# 1949-03-01     121.350588
# 1949-04-01     137.220921
# 1949-05-01     129.789181
# 1949-06-01     119.169153
#                  ...
# 2198-09-01    7713.956606
# 2198-10-01    7716.487355
# 2198-11-01    7719.018105
# 2198-12-01    7721.548855
# 2199-01-01    7724.079604
# Freq: MS, Length: 3000, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("d:\\data\\csv\\실습파일\\stock-data.csv")
df
# Out:
#           Date  Close  Start   High    Low  Volume
# 0   2018-07-02  10100  10850  10900  10000  137977
# 1   2018-06-29  10700  10550  10900   9990  170253
# 2   2018-06-28  10400  10900  10950  10150  155769
# 3   2018-06-27  10900  10800  11050  10500  133548
# 4   2018-06-26  10800  10900  11000  10700   63039
# 5   2018-06-25  11150  11400  11450  11000   55519
# 6   2018-06-22  11300  11250  11450  10750  134805
# 7   2018-06-21  11200  11350  11750  11200  133002
# 8   2018-06-20  11550  11200  11600  10900  308596
# 9   2018-06-19  11300  11850  11950  11300  180656
# 10  2018-06-18  12000  13400  13400  12000  309787
# 11  2018-06-15  13400  13600  13600  12900  201376
# 12  2018-06-14  13450  13200  13700  13150  347451
# 13  2018-06-12  13200  12200  13300  12050  558148
# 14  2018-06-11  11950  12000  12250  11950   62293
# 15  2018-06-08  11950  11950  12200  11800   59258
# 16  2018-06-07  11950  12200  12300  11900   49088
# ...

# %%
import pandas as pd
df['new_Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20 entries, 2018-07-02 to 2018-06-01
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   20 non-null     int64
#  1   Start   20 non-null     int64
#  2   High    20 non-null     int64
#  3   Low     20 non-null     int64
#  4   Volume  20 non-null     int64
# dtypes: int64(5)
# memory usage: 960.0 bytes

# %%
df.drop('Date', axis =1 , inplace = True)

# %%
df.set_index('new_Date', inplace = True)

# %%
df
# Out:
#             Close  Start   High    Low  Volume
# new_Date
# 2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  10800  10900  11000  10700   63039
# 2018-06-25  11150  11400  11450  11000   55519
# 2018-06-22  11300  11250  11450  10750  134805
# 2018-06-21  11200  11350  11750  11200  133002
# 2018-06-20  11550  11200  11600  10900  308596
# 2018-06-19  11300  11850  11950  11300  180656
# 2018-06-18  12000  13400  13400  12000  309787
# 2018-06-15  13400  13600  13600  12900  201376
# 2018-06-14  13450  13200  13700  13150  347451
# 2018-06-12  13200  12200  13300  12050  558148
# 2018-06-11  11950  12000  12250  11950   62293
# 2018-06-08  11950  11950  12200  11800   59258
# 2018-06-07  11950  12200  12300  11900   49088
# 2018-06-05  12150  11800  12250  11800   42485
# 2018-06-04  11900  11900  12200  11700   25171
# ...

# %%
df['Year'] = df['new_Date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new_Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-dfe6fbce9ec4> in <module>
# ----> 1 df['Year'] = df['new_Date'].dt.year
#
# ...

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
df
# Out:
#             Close  Start   High    Low  Volume  year  month  day
# new_Date
# 2018-07-02  10100  10850  10900  10000  137977  2018      7    2
# 2018-06-29  10700  10550  10900   9990  170253  2018      6   29
# 2018-06-28  10400  10900  10950  10150  155769  2018      6   28
# 2018-06-27  10900  10800  11050  10500  133548  2018      6   27
# 2018-06-26  10800  10900  11000  10700   63039  2018      6   26
# 2018-06-25  11150  11400  11450  11000   55519  2018      6   25
# 2018-06-22  11300  11250  11450  10750  134805  2018      6   22
# 2018-06-21  11200  11350  11750  11200  133002  2018      6   21
# 2018-06-20  11550  11200  11600  10900  308596  2018      6   20
# 2018-06-19  11300  11850  11950  11300  180656  2018      6   19
# 2018-06-18  12000  13400  13400  12000  309787  2018      6   18
# 2018-06-15  13400  13600  13600  12900  201376  2018      6   15
# 2018-06-14  13450  13200  13700  13150  347451  2018      6   14
# ...

# %%
df2 =df[['Close']]

# %%
df2.shape
df2.head()
df2.tail()
# Out:
#             Close
# new_Date
# 2018-06-08  11950
# 2018-06-07  11950
# 2018-06-05  12150
# 2018-06-04  11900
# 2018-06-01  11900

# %%
import pandas as pd
from statsmodels.tsa.arima_model import ARIMA

order = (2, 1, 2)
#model = ARIMA(df, order, freq='D')
model = ARIMA(df2, order)
fit = model.fit()
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\knit\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# C:\Users\knit\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\knit\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:222: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
# ...

# %%
## preds = fit.predict(1, 30, typ='levels')
print(preds)

# %%
def add_10(n):
    return n+10

import seaborn as sns
tat = sns.load_dataset('titanic')
sr1 = tat['age'].apply(add_10)
tat['age2'] = sr1
tat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
def age2(n):
    return n**2

import pandas as pd

insu = pd.read_csv('d:\\data\\csv\\insurance.csv')
insu['age2'] = insu['age'].apply(age2)
insu
# Out:
#       age     sex   bmi  children smoker     region  expenses  age2
# 0      19  female  27.9         0    yes  southwest  16884.92   361
# 1      18    male  33.8         1     no  southeast   1725.55   324
# 2      28    male  33.0         3     no  southeast   4449.46   784
# 3      33    male  22.7         0     no  northwest  21984.47  1089
# 4      32    male  28.9         0     no  northwest   3866.86  1024
# ...   ...     ...   ...       ...    ...        ...       ...   ...
# 1333   50    male  31.0         3     no  northwest  10600.55  2500
# 1334   18  female  31.9         0     no  northeast   2205.98   324
# 1335   18  female  36.9         0     no  southeast   1629.83   324
# 1336   21  female  25.8         0     no  southwest   2007.95   441
# 1337   61  female  29.1         0    yes  northwest  29141.36  3721
#
# [1338 rows x 8 columns]

# %%
	tat= sns.load_dataset('titanic')
	df = tat.loc[:,['age','fare']]

# %%
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
tat= sns.load_dataset('titanic')
df = tat.loc[:,['age','fare']]

def add_10(n):
	return n +10
	
df_map=df.applymap(add_10)
df_map.head()
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
import pandas as pd
tit = pd.read_csv('d:\\data\\csv\\train.csv')
tit['Name_length'] = tit['Name'].apply(len)
tit[['Name','Name_length']]
# Out:
#                                                   Name  Name_length
# 0                              Braund, Mr. Owen Harris           23
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           51
# 2                               Heikkinen, Miss. Laina           22
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           44
# 4                             Allen, Mr. William Henry           24
# ..                                                 ...          ...
# 886                              Montvila, Rev. Juozas           21
# 887                       Graham, Miss. Margaret Edith           28
# 888           Johnston, Miss. Catherine Helen "Carrie"           40
# 889                              Behr, Mr. Karl Howell           21
# 890                                Dooley, Mr. Patrick           19
#
# [891 rows x 2 columns]

# %%
import pandas as pd
tit = pd.read_csv('d:\\data\\csv\\train.csv')
tit['Name_length'] = tit['Name'].apply(len)
tit[['Name','Name_length']].sort_values(by='Name_length', ascending =False)
# Out:
#                                                   Name  Name_length
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...           82
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...           67
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...           65
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...           61
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...           57
# ..                                                 ...          ...
# 509                                     Lang, Mr. Fang           14
# 169                                      Ling, Mr. Lee           13
# 74                                       Bing, Mr. Lee           13
# 692                                       Lam, Mr. Ali           12
# 826                                       Lam, Mr. Len           12
#
# [891 rows x 2 columns]

# %%
import seaborn as sns
tat = sns.load_dataset('titanic')

df = tat.loc[:,['age','fare']]

# %%
def missing_value(ser):
    return ser.isnull().sum()

result =df.apply(missing_value,axis = 0)
result
# Out:
# age     177
# fare      0
# dtype: int64

# %%
ame = tit.Age.median()

tit.Age.fillna(ame, inplace =True)

tit.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
#1. 필요한 패키지를 import 한다. 
import  pandas  as  pd
import  seaborn  as  sns 

#1단계.  csv ---> 데이터 프레임으로 변환 
df = sns.load_dataset('titanic')

# 컬럼이 모두다 출력될 수 있도록 출력할 열의 개수 한도를 늘리기 
pd.set_option('display.max_columns', 15 ) 
# print  (df.head()  )

# print ( df.info()  ) 
# print ( '\n' )  

# print ( df.isnull().sum( axis=0)  )  
rdf =  df.drop(['deck', 'embark_town'] , axis= 1)
# print ( rdf.columns.values ) 

# 나이의 누락 데이터의 행을 삭제하라
meage = rdf['age'].median()
rdf['age'].fillna(meage,inplace=True)
#rdf = rdf.dropna( subset=['age'], how='any', axis= 0 )
# print ( len(rdf)  ) 
# print ('\n')

# 정박한 항구의 누락데이터 2건을 최빈값으로 채워라
most_freq = rdf['embarked'].value_counts(dropna=True).idxmax()
rdf['embarked'].fillna( most_freq, inplace=True ) 
# print ( rdf.isnull().sum(axis=0)  ) 


ndf = rdf[ ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked']] 
# print ( ndf.head()  )

# 명목형 더미변수 생성
gender = pd.get_dummies( ndf['sex'] )
ndf = pd.concat( [ndf, gender], axis=1 ) 

onehot_embarked = pd.get_dummies( ndf['embarked'], prefix='town')
ndf = pd.concat([ ndf, onehot_embarked], axis=1)
# 명목형 컬럼 2개 제거
ndf.drop( ['sex', 'embarked'],  axis=1, inplace=True )
# print ( ndf.head() ) 

#훈련할 학습데이터 x와 정답라벨 y 생성
X = ndf[ [ 'pclass' ,'age', 'sibsp','parch', 'female', 'male', 'town_C', 'town_Q',  'town_S']]
y = ndf['survived']   # 종속변수 

#4.2  독립변수들을 정규화(normalization) 한다. #표준화?

from  sklearn   import   preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
# print (X)

from  sklearn.model_selection  import   train_test_split
X_train, X_test, y_train, y_test =train_test_split( X, y, test_size=0.3, 
                                                           random_state = 10 ) 
                                                                    #ㄴ R에서 seed 값과 같음
# 설명:  test_size=0.3 에 의해서 7:3 비율로 훈련과 테스트를 나누고
# random_state=10 에 의해서 나중에 split 할 때도 항상 일정하게 
# split 할 수 있게 한다. 

print  ( 'train data 의 갯수:'  ,  X_train.shape )
print  ( 'test  data 의 갯수:'  ,  X_test.shape )

#knn머신러닝 모델로 학습 k=5
from  sklearn.neighbors  import   KNeighborsClassifier 

knn = KNeighborsClassifier( n_neighbors=5 ) 
knn.fit ( X_train, y_train )

# 사망자와 생존자를 예측
y_hat = knn.predict( X_test ) 

from  sklearn   import   metrics 
knn_matrix  =  metrics.confusion_matrix( y_test,  y_hat )
print ( knn_matrix ) 

# 모델의 정확도를 확인한다.
from sklearn.metrics import accuracy_score

accuracy = accuracy_score( y_test, y_hat)

print(accuracy)
# Out:
# train data 의 갯수: (623, 9)
# test  data 의 갯수: (268, 9)
# [[153  21]
#  [ 27  67]]
# 0.8208955223880597
