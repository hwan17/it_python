# %%
import pandas as pd
dict_data = {'a':1,'b':2,'c':3}
print(dict_data)
sr = pd.Series(dict_data) # 딕셔너리를 시리즈로 변환
print(sr)
print(type(sr))
sr[0]
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# a    1
# b    2
# c    3
# dtype: int64
# <class 'pandas.core.series.Series'>
# 1

# %% [markdown]
# case city 데이터 타입 확인

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")
c_case
type(c_case.city)
# Out:
#   File "<ipython-input-13-54df13e2063b>", line 5
#     type(c_case[,city])
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# 문제2. 코로나 case 데이터 프레임 모두 출력(중간에 ... 안나오게)

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")

print(c_case)
# Out:
#       case_id          province             city  group  \
# 0     1000001             Seoul       Yongsan-gu   True
# 1     1000002             Seoul        Gwanak-gu   True
# 2     1000003             Seoul          Guro-gu   True
# 3     1000004             Seoul     Yangcheon-gu   True
# 4     1000005             Seoul        Dobong-gu   True
# ..        ...               ...              ...    ...
# 169   6100012  Gyeongsangnam-do                -  False
# 170   7000001           Jeju-do                -  False
# 171   7000002           Jeju-do                -  False
# 172   7000003           Jeju-do                -  False
# 173   7000004           Jeju-do  from other city   True
#
#                   infection_case  confirmed   latitude   longitude
# 0                  Itaewon Clubs        139  37.538621  126.992652
# 1                        Richway        119   37.48208  126.901384
# 2            Guro-gu Call Center         95  37.508163  126.884387
# ...

# %% [markdown]
# 문제3. 코로나 case 데이터 프레임에 컬럼들이 뭐가 있는지 확인

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")
print(c_case.columns)
# Out:
# Index([' case_id', 'province', 'city', 'group', 'infection_case', 'confirmed',
#        'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# case_id : case 식별 번호
# province : 도시이름
# city : 구이름
# group : 집단감염 여부
# infection_case : 감염 경로
# confirmed : 누적 확진자 수
# latitude : 위도
# longitude : 경도

# %% [markdown]
# 문제4. 중간값 생략없이 전부 출력되게 하시오

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")
pd.set_option('display.max_columns',100)
c_case
# Out:
#       case_id          province             city  group  \
# 0     1000001             Seoul       Yongsan-gu   True
# 1     1000002             Seoul        Gwanak-gu   True
# 2     1000003             Seoul          Guro-gu   True
# 3     1000004             Seoul     Yangcheon-gu   True
# 4     1000005             Seoul        Dobong-gu   True
# ..        ...               ...              ...    ...
# 169   6100012  Gyeongsangnam-do                -  False
# 170   7000001           Jeju-do                -  False
# 171   7000002           Jeju-do                -  False
# 172   7000003           Jeju-do                -  False
# 173   7000004           Jeju-do  from other city   True
#
#                   infection_case  confirmed   latitude   longitude
# 0                  Itaewon Clubs        139  37.538621  126.992652
# 1                        Richway        119   37.48208  126.901384
# 2            Guro-gu Call Center         95  37.508163  126.884387
# ...

# %% [markdown]
# 문제5. emp3.csv를 불러와서 emp테이블의 모든 컬럼 확인

# %%
emp = pd.read_csv("d:\\data\\csv\\empcn.csv")
emp
# Out:
#     index  empno   ename        job     mgr         hiredate   sal    comm  \
# 0       1   7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN
# 1       2   7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN
# 2       3   7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN
# 3       4   7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN
# 4       5   7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0
# 5       6   7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0
# 6       7   7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0
# 7       8   7900   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN
# 8       9   7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0
# 9      10   7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN
# 10     11   7369   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN
# ...

# %%
import pandas as pd
list_data = ['a', 'b', 'c', 'd']
print(list_data)
sr = pd.Series(list_data)
print(sr)
print(sr.index)
print(sr.values)
# Out:
# ['a', 'b', 'c', 'd']
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object
# RangeIndex(start=0, stop=4, step=1)
# ['a' 'b' 'c' 'd']

# %% [markdown]
# 문제6. case 데이터 프레임에서 누적 확진자 수를 나타내는 confirmed의 값들을 빈 리스트 cf_num에 담으시오!

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")

#cf_num = list(c_case.confirmed)
cf_num = [c_case.confirmed]
cf_num
# Out:
# [0      139
#  1      119
#  2       95
#  3       43
#  4       43
#        ...
#  169     20
#  170     14
#  171      0
#  172      4
#  173      1
#  Name: confirmed, Length: 174, dtype: int64]

# %% [markdown]
# 문제7. 누적확진자 수의 평균을 출력하시오

# %%
import pandas as pd
import numpy as np
c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")

cf_num = list(c_case.confirmed)
#cf_num = [c_case.confirmed.values]
np.mean(cf_num)
# Out:
# 65.48850574712644

# %%
tup_data = ('영인','2020-01-28','여',True)
sr = pd.Series( tup_data, index=['이름','생년월일','성별','학생여부'])
print(sr[['이름','성별']])
# Out:
# 이름    영인
# 성별     여
# dtype: object

# %% [markdown]
# 문제8. 코로나 case에서 3개 원소 선택case_id, latitiude, longitude

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")
sr_loc = pd.Series(case[])

# %%
import pandas as pd

c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")
c_casecase_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-a510ec240487> in <module>
#       2
#       3 c_case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv")
# ----> 4 c_case.case_id
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'case_id'

# %%
import pandas as pd
dict_data = { 'c0': [1,2,3],'c1':[4,5,6],'c2':[6,7,8] }
df = pd.DataFrame(dict_data)
df
# Out:
#    c0  c1  c2
# 0   1   4   6
# 1   2   5   7
# 2   3   6   8

# %%
import pandas as pd
titanic = pd.read_csv("d:\\data\\csv\\train.csv")
df2 =titanic[["PassengerId","Survived","Pclass","Age"]][0:3]
df2
# Out:
#    PassengerId  Survived  Pclass   Age
# 0            1         0       3  22.0
# 1            2         1       1  38.0
# 2            3         1       3  26.0

# %%
import pandas as pd
titanic = pd.read_csv("d:\\data\\csv\\train.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 'PassengerId',
# 'Survived',
# 'Pclass', 승차권 클래스
# 'Name',
# 'Sex',
# 'Age',
# 'SibSp', 동반한 형제자매, 배우자 수
# 'Parch', 동반한 부모자식 수
# 'Ticket',
# 'Fare',
# 'Cabin',
# 'Embarked'

# %%
import pandas as pd
dates = pd.date_range('20190101',periods = 6)
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

print(np.random.randn(6,4))
# Out:
# [[-0.93652059 -0.65443955 -0.53388758  0.61110004]
#  [-1.87323436  0.69968344  0.35630616 -0.64618702]
#  [ 0.3261055  -0.92449568  0.77485962 -0.85810309]
#  [-1.07733747  0.48822246  0.30162392  1.50751845]
#  [ 0.28140722 -1.34198633 -1.15987332 -0.51462957]
#  [-1.0854811   1.10892257 -0.25464205 -1.30682541]]

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20190101',periods = 6)

df = pd.DataFrame( np.random.randn(6,4), index=dates, columns = list('ABCD'))

df
# Out:
#                    A         B         C         D
# 2019-01-01 -0.561011 -1.626973  0.831648 -0.072280
# 2019-01-02 -2.165733  0.938416 -0.171298 -0.890743
# 2019-01-03 -0.408912 -0.252024 -0.335204 -1.227530
# 2019-01-04  0.591081 -0.385959 -0.485746  0.133742
# 2019-01-05 -0.225478 -0.396040  1.384620 -0.980433
# 2019-01-06  0.348283  0.248673 -0.869182  0.558205

# %% [markdown]
# 위 df 데이터프레임에 독버섯(p)인지 정상 버섯(n)인지를 나타내는 라벨컬럼을 생성하시오

# %%
k=pd.Categorical(['p','p','n','n','p','n'])
k
# Out:
# [p, p, n, n, p, n]
# Categories (2, object): [n, p]

# %% [markdown]
# 문제10. 위 코드를 이용해서 df에 f라벨컬럼 추가

# %%
import pandas as pd
import numpy as np
dates = pd.date_range('20190101',periods = 6)

df = pd.DataFrame( np.random.randn(6,4), index=dates, columns = list('ABCD'))
k=pd.Categorical(['p','p','n','n','p','n'])
df["F"]=k
print(df)
# Out:
#                    A         B         C         D  F
# 2019-01-01 -0.708701 -0.039192  1.925158  0.208843  p
# 2019-01-02 -0.090849 -0.067674  2.019905  0.827068  p
# 2019-01-03  1.449019 -1.893977 -0.116811 -0.031585  n
# 2019-01-04 -0.301067  1.317921  0.744189  0.908299  n
# 2019-01-05 -1.572233  0.214234  0.063666 -0.851496  p
# 2019-01-06  0.295732 -1.228378  1.641253  1.386472  n

# %%
df = pd.DataFrame([[15,'남','역삼중'],[14,'여','역삼중']], index=['준서','예은'],columns=['나이','성별','학교'])
df
# Out:
#     나이 성별   학교
# 준서  15  남  역삼중
# 예은  14  여  역삼중

# %%
df.rename(columns={'나이':'연령','성별':'남녀','학교':'소속'}, inplace = True)
df.rename(index={'준서':'학생1','예은':'학생2'}, inplace = True)
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  역삼중
# 학생2  14  여  역삼중

# %%
df2 = df.rename(index={'학생1':'준서','학생2':'예은'}, columns = {'연령':'나이','남녀':'성별','소속':'학교'}, inplace = False)
df2
# Out:
#     나이 성별   학교
# 준서  15  남  역삼중
# 예은  14  여  역삼중

# %% [markdown]
# 문제12.

# %%
import pandas as pd
import numpy as np

c = pd.DataFrame([[90, 98, 85, 100], [80, 89, 95, 90], [70, 95, 100, 90]],
                 index=['서준', '우현', '인아'],
                 columns=['수학', '영어', '음악', '체육'])
c
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
exam_data = {'수학':[90,80,70], '영어':[98,89,95],'음악':[85,95,100],'체육':[100,90,90]}
c2 = pd.DataFrame(exam_data, index=['서준','우현','인아'])
c2
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df3 = c2[:]
df3
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df3.drop('우현',axis =0, inplace = True)
print(df3)
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 인아  70  95  100   90
# C:\Users\knit\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df3['영어']
# Out:
# 서준    98
# 인아    95
# Name: 영어, dtype: int64

# %%
#df3.drop('영어',axis=1,inplace=True)
df3.수학
# Out:
# 서준    90
# 인아    70
# Name: 수학, dtype: int64

# %%
emp[emp.job=='SALESMAN']

print(emp)
# Out:
#     index  empno   ename        job     mgr         hiredate   sal    comm  \
# 0       1   7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN
# 1       2   7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN
# 2       3   7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN
# 3       4   7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN
# 4       5   7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0
# 5       6   7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0
# 6       7   7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0
# 7       8   7900   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN
# 8       9   7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0
# 9      10   7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN
# 10     11   7369   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN
# ...

# %%
emp = pd.read_csv("d:\\data\\csv\\empcn.csv", index_col = 'job')
emp
# Out:
#            index  empno   ename     mgr         hiredate   sal    comm  deptno
# job
# PRESIDENT      1   7839    KING     NaN  1981-11-17 0:00  5000     NaN      10
# MANAGER        2   7698   BLAKE  7839.0  1981-05-01 0:00  2850     NaN      30
# MANAGER        3   7782   CLARK  7839.0  1981-05-09 0:00  2450     NaN      10
# MANAGER        4   7566   JONES  7839.0  1981-04-01 0:00  2975     NaN      20
# SALESMAN       5   7654  MARTIN  7698.0  1981-09-10 0:00  1250  1400.0      30
# SALESMAN       6   7499   ALLEN  7698.0  1981-02-11 0:00  1600   300.0      30
# SALESMAN       7   7844  TURNER  7698.0  1981-08-21 0:00  1500     0.0      30
# CLERK          8   7900   JAMES  7698.0  1981-12-11 0:00   950     NaN      30
# SALESMAN       9   7521    WARD  7698.0  1981-02-23 0:00  1250   500.0      30
# ANALYST       10   7902    FORD  7566.0  1981-12-11 0:00  3000     NaN      20
# CLERK         11   7369   SMITH  7902.0  1980-12-09 0:00   800     NaN      20
# ...

# %%
emp_t = emp[:]

# %%
emp.drop('SALESMAN',axis =0, inplace=True)
emp
# Out:
#            index  empno   ename     mgr         hiredate   sal  comm  deptno
# job
# PRESIDENT      1   7839    KING     NaN  1981-11-17 0:00  5000   NaN      10
# MANAGER        2   7698   BLAKE  7839.0  1981-05-01 0:00  2850   NaN      30
# MANAGER        3   7782   CLARK  7839.0  1981-05-09 0:00  2450   NaN      10
# MANAGER        4   7566   JONES  7839.0  1981-04-01 0:00  2975   NaN      20
# CLERK          8   7900   JAMES  7698.0  1981-12-11 0:00   950   NaN      30
# ANALYST       10   7902    FORD  7566.0  1981-12-11 0:00  3000   NaN      20
# CLERK         11   7369   SMITH  7902.0  1980-12-09 0:00   800   NaN      20
# ANALYST       12   7788   SCOTT  7566.0  1982-12-22 0:00  3000   NaN      20
# CLERK         13   7876   ADAMS  7788.0  1983-01-15 0:00  1100   NaN      20
# CLERK         14   7934  MILLER  7782.0  1982-01-11 0:00  1300   NaN      10

# %%
df3.loc['서준']
# Out:
# 수학     90
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
df3[1:2]
# Out:
#     수학   음악  체육
# 인아  70  100  90

# %%
c_case[c_case.infection_case=="Itaewon Clubs"]
# Out:
#       case_id           province             city  group infection_case  \
# 0     1000001              Seoul       Yongsan-gu   True  Itaewon Clubs
# 43    1100006              Busan  from other city   True  Itaewon Clubs
# 53    1200006              Daegu  from other city   True  Itaewon Clubs
# 63    1400001            Incheon  from other city   True  Itaewon Clubs
# 92    2000003        Gyeonggi-do  from other city   True  Itaewon Clubs
# 121   4000002  Chungcheongbuk-do  from other city   True  Itaewon Clubs
# 135   5000001       Jeollabuk-do  from other city   True  Itaewon Clubs
# 165   6100008   Gyeongsangnam-do  from other city   True  Itaewon Clubs
# 173   7000004            Jeju-do  from other city   True  Itaewon Clubs
#
#      confirmed   latitude   longitude
# 0          139  37.538621  126.992652
# 43           4          -           -
# 53           2          -           -
# 63          53          -           -
# 92          59          -           -
# ...

# %%
case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv", index_col = 'infection_case')
case
case.loc['Itaewon Clubs']
# Out:
#                  case_id           province             city  group  \
# infection_case
# Itaewon Clubs    1000001              Seoul       Yongsan-gu   True
# Itaewon Clubs    1100006              Busan  from other city   True
# Itaewon Clubs    1200006              Daegu  from other city   True
# Itaewon Clubs    1400001            Incheon  from other city   True
# Itaewon Clubs    2000003        Gyeonggi-do  from other city   True
# Itaewon Clubs    4000002  Chungcheongbuk-do  from other city   True
# Itaewon Clubs    5000001       Jeollabuk-do  from other city   True
# Itaewon Clubs    6100008   Gyeongsangnam-do  from other city   True
# Itaewon Clubs    7000004            Jeju-do  from other city   True
#
#                 confirmed   latitude   longitude
# infection_case
# Itaewon Clubs         139  37.538621  126.992652
# Itaewon Clubs           4          -           -
# Itaewon Clubs           2          -           -
# Itaewon Clubs          53          -           -
# ...

# %%
c_case[(c_case.infection_case=="Itaewon Clubs") | (c_case.infection_case=="Richway")]
# Out:
#       case_id           province             city  group infection_case  \
# 0     1000001              Seoul       Yongsan-gu   True  Itaewon Clubs
# 1     1000002              Seoul        Gwanak-gu   True        Richway
# 43    1100006              Busan  from other city   True  Itaewon Clubs
# 53    1200006              Daegu  from other city   True  Itaewon Clubs
# 63    1400001            Incheon  from other city   True  Itaewon Clubs
# 92    2000003        Gyeonggi-do  from other city   True  Itaewon Clubs
# 93    2000004        Gyeonggi-do  from other city   True        Richway
# 115   3000004         Gangwon-do  from other city   True        Richway
# 121   4000002  Chungcheongbuk-do  from other city   True  Itaewon Clubs
# 130   4100004  Chungcheongnam-do  from other city   True        Richway
# 135   5000001       Jeollabuk-do  from other city   True  Itaewon Clubs
# 165   6100008   Gyeongsangnam-do  from other city   True  Itaewon Clubs
# ...

# %%
case = pd.read_csv("d:\\data\\csv\\corona\\Case.csv", index_col = 'infection_case')
case
case.loc[['Itaewon Clubs','Richway']]
# Out:
#                  case_id           province             city  group  \
# infection_case
# Itaewon Clubs    1000001              Seoul       Yongsan-gu   True
# Itaewon Clubs    1100006              Busan  from other city   True
# Itaewon Clubs    1200006              Daegu  from other city   True
# Itaewon Clubs    1400001            Incheon  from other city   True
# Itaewon Clubs    2000003        Gyeonggi-do  from other city   True
# Itaewon Clubs    4000002  Chungcheongbuk-do  from other city   True
# Itaewon Clubs    5000001       Jeollabuk-do  from other city   True
# Itaewon Clubs    6100008   Gyeongsangnam-do  from other city   True
# Itaewon Clubs    7000004            Jeju-do  from other city   True
# Richway          1000002              Seoul        Gwanak-gu   True
# Richway          2000004        Gyeonggi-do  from other city   True
# Richway          3000004         Gangwon-do  from other city   True
# Richway          4100004  Chungcheongnam-do  from other city   True
# ...

# %%
c_case[:3]
# Out:
#     case_id province        city  group       infection_case  confirmed  \
# 0   1000001    Seoul  Yongsan-gu   True        Itaewon Clubs        139
# 1   1000002    Seoul   Gwanak-gu   True              Richway        119
# 2   1000003    Seoul     Guro-gu   True  Guro-gu Call Center         95
#
#     latitude   longitude
# 0  37.538621  126.992652
# 1   37.48208  126.901384
# 2  37.508163  126.884387

# %%
c_case.head(10)
# Out:
#     case_id province             city  group  \
# 0   1000001    Seoul       Yongsan-gu   True
# 1   1000002    Seoul        Gwanak-gu   True
# 2   1000003    Seoul          Guro-gu   True
# 3   1000004    Seoul     Yangcheon-gu   True
# 4   1000005    Seoul        Dobong-gu   True
# 5   1000006    Seoul          Guro-gu   True
# 6   1000007    Seoul  from other city   True
# 7   1000008    Seoul    Dongdaemun-gu   True
# 8   1000009    Seoul  from other city   True
# 9   1000010    Seoul        Gwanak-gu   True
#
#                      infection_case  confirmed   latitude   longitude
# 0                     Itaewon Clubs        139  37.538621  126.992652
# 1                           Richway        119   37.48208  126.901384
# 2               Guro-gu Call Center         95  37.508163  126.884387
# 3       Yangcheon Table Tennis Club         43  37.546061  126.874209
# 4                   Day Care Center         43  37.679422  127.044374
# ...

# %%
c_case.iloc[-3:
           ]
# Out:
#       case_id province             city  group        infection_case  \
# 171   7000002  Jeju-do                -  False  contact with patient
# 172   7000003  Jeju-do                -  False                   etc
# 173   7000004  Jeju-do  from other city   True         Itaewon Clubs
#
#      confirmed latitude longitude
# 171          0        -         -
# 172          4        -         -
# 173          1        -         -

# %%
c_case.tail(3)
# Out:
#       case_id province             city  group        infection_case  \
# 171   7000002  Jeju-do                -  False  contact with patient
# 172   7000003  Jeju-do                -  False                   etc
# 173   7000004  Jeju-do  from other city   True         Itaewon Clubs
#
#      confirmed latitude longitude
# 171          0        -         -
# 172          4        -         -
# 173          1        -         -

# %%
c_case[[' case_id','group']]
# Out:
#       case_id  group
# 0     1000001   True
# 1     1000002   True
# 2     1000003   True
# 3     1000004   True
# 4     1000005   True
# ..        ...    ...
# 169   6100012  False
# 170   7000001  False
# 171   7000002  False
# 172   7000003  False
# 173   7000004   True
#
# [174 rows x 2 columns]

# %%
pd.DataFrame[' case_id','group']
case. case_id
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-252-1243d2c61e84> in <module>
# ----> 1 pd.DataFrame[' case_id','group']
#       2 case. case_id
#
# TypeError: 'type' object is not subscriptable

# %%
c_case.rename(columns = {' case_id':'case_id'}, inplace=True)

# %%
c_case.case_id
# Out:
# 0      1000001
# 1      1000002
# 2      1000003
# 3      1000004
# 4      1000005
#         ...
# 169    6100012
# 170    7000001
# 171    7000002
# 172    7000003
# 173    7000004
# Name: case_id, Length: 174, dtype: int64

# %%
pd.DataFrame([c_case.case_id, c_case.group]).T
# Out:
#      case_id  group
# 0    1000001      1
# 1    1000002      1
# 2    1000003      1
# 3    1000004      1
# 4    1000005      1
# ..       ...    ...
# 169  6100012      0
# 170  7000001      0
# 171  7000002      0
# 172  7000003      0
# 173  7000004      1
#
# [174 rows x 2 columns]

# %%
c_case[:10:]
# Out:
#    case_id province             city  group                    infection_case  \
# 0  1000001    Seoul       Yongsan-gu   True                     Itaewon Clubs
# 1  1000002    Seoul        Gwanak-gu   True                           Richway
# 2  1000003    Seoul          Guro-gu   True               Guro-gu Call Center
# 3  1000004    Seoul     Yangcheon-gu   True       Yangcheon Table Tennis Club
# 4  1000005    Seoul        Dobong-gu   True                   Day Care Center
# 5  1000006    Seoul          Guro-gu   True             Manmin Central Church
# 6  1000007    Seoul  from other city   True  SMR Newly Planted Churches Group
# 7  1000008    Seoul    Dongdaemun-gu   True                     Dongan Church
# 8  1000009    Seoul  from other city   True          Coupang Logistics Center
# 9  1000010    Seoul        Gwanak-gu   True                   Wangsung Church
#
#    confirmed   latitude   longitude
# 0        139  37.538621  126.992652
# 1        119   37.48208  126.901384
# ...

# %%
c_case[::-1]
# Out:
#      case_id          province             city  group  \
# 173  7000004           Jeju-do  from other city   True
# 172  7000003           Jeju-do                -  False
# 171  7000002           Jeju-do                -  False
# 170  7000001           Jeju-do                -  False
# 169  6100012  Gyeongsangnam-do                -  False
# ..       ...               ...              ...    ...
# 4    1000005             Seoul        Dobong-gu   True
# 3    1000004             Seoul     Yangcheon-gu   True
# 2    1000003             Seoul          Guro-gu   True
# 1    1000002             Seoul        Gwanak-gu   True
# 0    1000001             Seoul       Yongsan-gu   True
#
#                   infection_case  confirmed   latitude   longitude
# 173                Itaewon Clubs          1          -           -
# 172                          etc          4          -           -
# 171         contact with patient          0          -           -
# ...

# %%
pf = pd.read_csv("d:\\data\\csv\\corona\\PatientInfo.csv", index_col = 'patient_id')
pf.head()
# Out:
#                sex  age country province         city        infection_case  \
# patient_id
# 1000000001    male  50s   Korea    Seoul   Gangseo-gu       overseas inflow
# 1000000002    male  30s   Korea    Seoul  Jungnang-gu       overseas inflow
# 1000000003    male  50s   Korea    Seoul    Jongno-gu  contact with patient
# 1000000004    male  20s   Korea    Seoul      Mapo-gu       overseas inflow
# 1000000005  female  20s   Korea    Seoul  Seongbuk-gu  contact with patient
#
#            infected_by contact_number symptom_onset_date confirmed_date  \
# patient_id
# 1000000001         NaN             75         2020-01-22     2020-01-23
# 1000000002         NaN             31                NaN     2020-01-30
# 1000000003  2002000001             17                NaN     2020-01-30
# 1000000004         NaN              9         2020-01-26     2020-01-30
# 1000000005  1000000002              2                NaN     2020-01-31
#
#            released_date deceased_date     state
# ...

# %%
df3
# Out:
#     수학   음악   체육
# 서준  90   85  100
# 인아  70  100   90

# %%
pf = pd.read_csv("d:\\data\\csv\\corona\\PatientInfo.csv", index_col = 'patient_id')
pf.loc[1000000010,'infected_by']
# Out:
# '1000000003'

# %%
pf2 = pd.read_csv("d:\\data\\csv\\corona\\PatientInfo.csv")
pf2[pf2.patient_id==1000000010][["infected_by"]]
# Out:
#   infected_by
# 9  1000000003

# %%
df3
# Out:
#     수학   음악   체육  국어
# 서준  90   85  100  80
# 인아  70  100   90  80

# %%
titanic['Age2']=titanic.Age**2

# %%
titanic.shape
# Out:
# (891, 13)

# %%
df3.loc['동규'] = 1

# %%
df3
# Out:
#     수학   음악   체육  국어
# 서준  90   85  100  80
# 인아  70  100   90  80
# 동규   1    1    1   1

# %%
df3.loc['현수'] = [90,97,93,89]

# %%
df3
# Out:
#     수학   음악   체육  국어
# 서준  90   85  100  80
# 인아  70  100   90  80
# 동규   1    1    1   1
# 현수  90   97   93  89

# %%
k = list((90,97,93,89))
k
# Out:
# [90, 97, 93, 89]

# %%
# Out:
#   File "<ipython-input-323-de6957cfd5d3>", line 1
#     df3.loc[,'국어']
#             ^
# SyntaxError: invalid syntax

# %%
df3.loc['동규']['체육'] = 90

# %%
df3
# Out:
#     수학   음악   체육   국어
# 서준  90   85  100  100
# 인아  70  100   90   80
# 동규   1    1   90    1
# 현수  90   97   93   89

# %%
df3.T
# Out:
#      서준   인아  동규  현수
# 수학   90   70   1  90
# 음악   85  100   1  97
# 체육  100   90  90  93
# 국어  100   80   1  89

# %%
df3.transpose()
# Out:
#      서준   인아  동규  현수
# 수학   90   70   1  90
# 음악   85  100   1  97
# 체육  100   90  90  93
# 국어  100   80   1  89

# %%
df3
# Out:
#     수학   음악   체육   국어
# 서준  90   85  100  100
# 인아  70  100   90   80
# 동규   1    1   90    1
# 현수  90   97   93   89

# %%
import pandas as pd
emp = pd.read_csv("d:\\data\\csv\\empcn.csv")
print(emp.isnull())
print(emp['comm'].isnull())
print(emp.comm.isnull())
# Out:
#     index  empno  ename    job    mgr  hiredate    sal   comm  deptno
# 0   False  False  False  False   True     False  False   True   False
# 1   False  False  False  False  False     False  False   True   False
# 2   False  False  False  False  False     False  False   True   False
# 3   False  False  False  False  False     False  False   True   False
# 4   False  False  False  False  False     False  False  False   False
# 5   False  False  False  False  False     False  False  False   False
# 6   False  False  False  False  False     False  False  False   False
# 7   False  False  False  False  False     False  False   True   False
# 8   False  False  False  False  False     False  False  False   False
# 9   False  False  False  False  False     False  False   True   False
# 10  False  False  False  False  False     False  False   True   False
# 11  False  False  False  False  False     False  False   True   False
# ...

# %%
emp.comm.isnull().sum()
# Out:
# 10

# %%
emp['comm']=emp['comm'].fillna(0)

# %%
emp
# Out:
#     index  empno   ename        job     mgr         hiredate   sal    comm  \
# 0       1   7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     0.0
# 1       2   7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     0.0
# 2       3   7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     0.0
# 3       4   7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     0.0
# 4       5   7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0
# 5       6   7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0
# 6       7   7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0
# 7       8   7900   JAMES      CLERK  7698.0  1981-12-11 0:00   950     0.0
# 8       9   7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0
# 9      10   7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     0.0
# 10     11   7369   SMITH      CLERK  7902.0  1980-12-09 0:00   800     0.0
# ...

# %%
emp.sort_values(by="sal",ascending = False)
# Out:
#     index  empno   ename        job     mgr         hiredate   sal    comm  \
# 0       1   7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     0.0
# 9      10   7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     0.0
# 11     12   7788   SCOTT    ANALYST  7566.0  1982-12-22 0:00  3000     0.0
# 3       4   7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     0.0
# 1       2   7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     0.0
# 2       3   7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     0.0
# 5       6   7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0
# 6       7   7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0
# 13     14   7934  MILLER      CLERK  7782.0  1982-01-11 0:00  1300     0.0
# 4       5   7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0
# 8       9   7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0
# ...

# %%
pf2['cnt']=list(pf2[['infected_by','patient_id']].groupby('infected_by')['patient_id'].count())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-373-f2090a7da7ff> in <module>
# ----> 1 pf2['cnt']=list(pf2[['infected_by','patient_id']].groupby('infected_by')['patient_id'].count())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# ...

# %%
pf2[['infected_by','patient_id']].groupby('infected_by')['patient_id'].count().reset_index().sort_values(by='patient_id',ascending = False)
# Out:
#     infected_by  patient_id
# 340  2000000205          51
# 483  4100000008          27
# 335  2000000167          24
# 213  1400000209          24
# 356  2000000309          21
# ..          ...         ...
# 242  1400000321           1
# 240  1400000302           1
# 239  1400000301           1
# 238  1400000299           1
# 605  7000000009           1
#
# [606 rows x 2 columns]
