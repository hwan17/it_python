# %%
import pandas as pd

df1 = pd.read_csv("d:\\data\\csv\\empcn.csv", header=0)
df1
# Out:
#     index  empno   ename        job     mgr         hiredate   sal    comm  \
# 0       1   7839    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN
# 1       2   7698   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN
# 2       3   7782   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN
# 3       4   7566   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN
# 4       5   7654  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0
# 5       6   7499   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0
# 6       7   7844  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0
# 7       8   7900   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN
# 8       9   7521    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0
# 9      10   7902    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN
# 10     11   7369   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN
# ...

# %%
import pandas as pd

df1 = pd.read_csv("d:\\data\\csv\\empcn.csv", header=None)
df1
# Out:
#         0      1       2          3     4                5     6     7       8
# 0   index  empno   ename        job   mgr         hiredate   sal  comm  deptno
# 1       1   7839    KING  PRESIDENT   NaN  1981-11-17 0:00  5000   NaN      10
# 2       2   7698   BLAKE    MANAGER  7839  1981-05-01 0:00  2850   NaN      30
# 3       3   7782   CLARK    MANAGER  7839  1981-05-09 0:00  2450   NaN      10
# 4       4   7566   JONES    MANAGER  7839  1981-04-01 0:00  2975   NaN      20
# 5       5   7654  MARTIN   SALESMAN  7698  1981-09-10 0:00  1250  1400      30
# 6       6   7499   ALLEN   SALESMAN  7698  1981-02-11 0:00  1600   300      30
# 7       7   7844  TURNER   SALESMAN  7698  1981-08-21 0:00  1500     0      30
# 8       8   7900   JAMES      CLERK  7698  1981-12-11 0:00   950   NaN      30
# 9       9   7521    WARD   SALESMAN  7698  1981-02-23 0:00  1250   500      30
# 10     10   7902    FORD    ANALYST  7566  1981-12-11 0:00  3000   NaN      20
# ...

# %%
import pandas as pd

df1 = pd.read_csv("d:\\data\\csv\\empcn.csv", index_col = 'empno')
df1
# Out:
#        index   ename        job     mgr         hiredate   sal    comm  deptno
# empno
# 7839       1    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN      10
# 7698       2   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN      30
# 7782       3   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN      10
# 7566       4   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN      20
# 7654       5  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0      30
# 7499       6   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0      30
# 7844       7  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0      30
# 7900       8   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN      30
# 7521       9    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0      30
# 7902      10    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN      20
# 7369      11   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN      20
# ...

# %%
df1.loc[7788]['sal']
# Out:
# 3000

# %%
df1.sal.loc[7788]
# Out:
# 3000

# %%
df2 = pd.read_csv("d:\\data\\csv\\train.csv", index_col = 'Survived')
df2.head()

len(df2.loc[1])
# Out:
# 342

# %%
import pandas as pd

df1 = pd.read_excel('d:\\data\\csv\\실습파일\\남북한발전전력량.xlsx')
df1
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
df1.iloc[2,-1]
# Out:
# 3523

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')
emp
emp['sal_lagged'] = emp['sal'].shift(1)
emp[['ename','sal','sal_lagged']]
# Out:
#      ename   sal  sal_lagged
# 0     KING  5000         NaN
# 1    BLAKE  2850      5000.0
# 2    CLARK  2450      2850.0
# 3    JONES  2975      2450.0
# 4   MARTIN  1250      2975.0
# 5    ALLEN  1600      1250.0
# 6   TURNER  1500      1600.0
# 7    JAMES   950      1500.0
# 8     WARD  1250       950.0
# 9     FORD  3000      1250.0
# 10   SMITH   800      3000.0
# 11   SCOTT  3000       800.0
# 12   ADAMS  1100      3000.0
# 13  MILLER  1300      1100.0

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')
emp['sal_lagged'] = emp['sal'].shift(1)
emp['sal_c'] = emp['sal'] - emp['sal_lagged']
emp[['ename','sal','sal_c']]
# Out:
#      ename   sal   sal_c
# 0     KING  5000     NaN
# 1    BLAKE  2850 -2150.0
# 2    CLARK  2450  -400.0
# 3    JONES  2975   525.0
# 4   MARTIN  1250 -1725.0
# 5    ALLEN  1600   350.0
# 6   TURNER  1500  -100.0
# 7    JAMES   950  -550.0
# 8     WARD  1250   300.0
# 9     FORD  3000  1750.0
# 10   SMITH   800 -2200.0
# 11   SCOTT  3000  2200.0
# 12   ADAMS  1100 -1900.0
# 13  MILLER  1300   200.0

# %%
a = 'dkwgn'
b = '293jg2ol'

(a+b).count('k')
# Out:
# 1

# %%
time = pd.read_csv('d:\\data\\csv\\corona\\Time.csv')
time['cnt_d'] = time.confirmed - time.confirmed.shift(1)
time['cnt_d'] 
time
# Out:
#            date  time     test  negative  confirmed  released  deceased  cnt_d
# 0    2020-01-20    16        1         0          1         0         0    NaN
# 1    2020-01-21    16        1         0          1         0         0    0.0
# 2    2020-01-22    16        4         3          1         0         0    0.0
# 3    2020-01-23    16       22        21          1         0         0    0.0
# 4    2020-01-24    16       27        25          2         0         0    1.0
# ..          ...   ...      ...       ...        ...       ...       ...    ...
# 158  2020-06-26     0  1232315   1200885      12602     11172       282   39.0
# 159  2020-06-27     0  1243780   1211261      12653     11317       282   51.0
# 160  2020-06-28     0  1251695   1219975      12715     11364       282   62.0
# 161  2020-06-29     0  1259954   1228698      12757     11429       282   42.0
# 162  2020-06-30     0  1273766   1240157      12800     11537       282   43.0
#
# [163 rows x 8 columns]

# %%
time = pd.read_csv('d:\\data\\csv\\corona\\Time.csv')
time['cnt_d'] = time.confirmed - time.confirmed.shift(1)
time['cnt_d']
k = time.plot(kind='line',x='date',y='cnt_d')
k.set_xticklabels(time.date, rotation=30)
# Out:
# [Text(0, 0, '2020-01-20'),
#  Text(0, 0, '2020-01-21'),
#  Text(0, 0, '2020-01-22'),
#  Text(0, 0, '2020-01-23'),
#  Text(0, 0, '2020-01-24'),
#  Text(0, 0, '2020-01-25'),
#  Text(0, 0, '2020-01-26'),
#  Text(0, 0, '2020-01-27'),
#  Text(0, 0, '2020-01-28'),
#  Text(0, 0, '2020-01-29'),
#  Text(0, 0, '2020-01-30')]

# %%
df1 = pd.read_json("d:\\data\\csv\\실습파일\\read_json_sample.json")
df1.head()
df1.index
df1.keys()
df1.values
df1
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %%
df1['NumPy':'NumPy']['developer']
# Out:
# NumPy    Travis Oliphant
# Name: developer, dtype: object

# %%
df1.loc['NumPy','developer']
# Out:
# 'Travis Oliphant'

# %%
df1.loc['pandas','year']
# Out:
# 2008

# %%
url = pd.read_html("d:\\data\\csv\\실습파일\\sample.html")
url[:]
# Out:
# [   Unnamed: 0  c0  c1  c2  c3
#  0           0   0   1   4   7
#  1           1   1   2   5   8
#  2           2   2   3   6   9,
#           name  year        developer  opensource
#  0       NumPy  2006  Travis Oliphant        True
#  1  matplotlib  2003   John D. Hunter        True
#  2      pandas  2008    Wes Mckinneye        True]

# %%
# Out:
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9

# %%
url2 = pd.read_html("d:\\data\\csv\\실습파일\\sample2.html")
dcnt = url2[5][2].str.split('+').str[1].str.split(')').str[0]
d = url2[5][1]
dcnt

r = pd.DataFrame({'date':d, 'cnt':dcnt})[2:-2]
r

#k['n'] = k[2]
#k
#url2[5][2][2:-2].str.split('+')
# Out:
#        date cnt
# 2    1월 20일   1
# 3    1월 24일   1
# 4    1월 26일   1
# 5    1월 27일   1
# 6    1월 30일   1
# ..      ...  ..
# 162   7월 8일  62
# 163   7월 9일  50
# 164  7월 10일  45
# 165  7월 11일  35
# 166  7월 12일  44
#
# [165 rows x 2 columns]

# %%
url2 = pd.read_html("d:\\data\\csv\\실습파일\\sample2.html")
url2[5]
# Out:
#                    0                1                2                3  \
# 0                NaN              NaN              NaN              NaN
# 1                 연도               날짜           누적 확진자           누적 사망자
# 2              2020년           1월 20일          1명 (+1)               0명
# 3              2020년           1월 24일          1명 (+1)               0명
# 4              2020년           1월 26일          2명 (+1)               0명
# ..               ...              ...              ...              ...
# 164            2020년           7월 10일    13,338명 (+45)        288명 (+1)
# 165            2020년           7월 11일    13,373명 (+35)        288명 (+1)
# 166            2020년           7월 12일    13,417명 (+44)        289명 (+1)
# 167  2020년 7월 12일 현재  2020년 7월 12일 현재  2020년 7월 12일 현재  2020년 7월 12일 현재
# 168    v • d • e • h    v • d • e • h    v • d • e • h    v • d • e • h
#
#                    4
# 0                NaN
# 1           누적 격리해제자
# 2                 0명
# ...

# %%
url2 = pd.read_html("d:\\data\\csv\\실습파일\\sample2.html" )
url2[5][1]
# Out:
# 0                  NaN
# 1                   날짜
# 2               1월 20일
# 3               1월 24일
# 4               1월 26일
#             ...
# 164             7월 10일
# 165             7월 11일
# 166             7월 12일
# 167    2020년 7월 12일 현재
# 168      v • d • e • h
# Name: 1, Length: 169, dtype: object

# %%
emp.to_csv('d:\\data\\emp900.csv')

# %%
url2 = pd.read_html("d:\\data\\csv\\실습파일\\sample2.html")
dcnt = url2[5][2].str.split('+').str[1].str.split(')').str[0]
d = url2[5][1]
dcnt

r = pd.DataFrame({'date':d, 'cnt':dcnt})[2:-2]
r

# %%
r.to_csv('d:\\data\\csv\\cov0713.csv')

# %%
emp = pd.read_csv('d:\\data\\csv\\empcn.csv')
emp.set_index("empno",inplace=True)
emp
#emp.to_excel('d:\\data\\emp.xlsx')
# Out:
#        index   ename        job     mgr         hiredate   sal    comm  deptno
# empno
# 7839       1    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN      10
# 7698       2   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN      30
# 7782       3   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN      10
# 7566       4   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN      20
# 7654       5  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0      30
# 7499       6   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0      30
# 7844       7  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0      30
# 7900       8   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN      30
# 7521       9    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0      30
# 7902      10    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN      20
# 7369      11   SMITH      CLERK  7902.0  1980-12-09 0:00   800     NaN      20
# ...

# %%
r.to_excel('d:\\data\\cov0713.xlsx')

# %%
emp1 = pd.read_csv('d:\\data\\csv\\empcn.csv', index=False)
emp1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-262-f786151ce9f1> in <module>
# ----> 1 emp1 = pd.read_csv('d:\\data\\csv\\empcn.csv', index=False)
#       2 emp1
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
emp.head(10)
# Out:
#        index   ename        job     mgr         hiredate   sal    comm  deptno
# empno
# 7839       1    KING  PRESIDENT     NaN  1981-11-17 0:00  5000     NaN      10
# 7698       2   BLAKE    MANAGER  7839.0  1981-05-01 0:00  2850     NaN      30
# 7782       3   CLARK    MANAGER  7839.0  1981-05-09 0:00  2450     NaN      10
# 7566       4   JONES    MANAGER  7839.0  1981-04-01 0:00  2975     NaN      20
# 7654       5  MARTIN   SALESMAN  7698.0  1981-09-10 0:00  1250  1400.0      30
# 7499       6   ALLEN   SALESMAN  7698.0  1981-02-11 0:00  1600   300.0      30
# 7844       7  TURNER   SALESMAN  7698.0  1981-08-21 0:00  1500     0.0      30
# 7900       8   JAMES      CLERK  7698.0  1981-12-11 0:00   950     NaN      30
# 7521       9    WARD   SALESMAN  7698.0  1981-02-23 0:00  1250   500.0      30
# 7902      10    FORD    ANALYST  7566.0  1981-12-11 0:00  3000     NaN      20

# %%
emp.dtypes
# Out:
# index         int64
# ename        object
# job          object
# mgr         float64
# hiredate     object
# sal           int64
# comm        float64
# deptno        int64
# dtype: object

# %%
emp.shape
# Out:
# (14, 8)

# %%
emp.describe()
# Out:
#          index          mgr          sal         comm     deptno
# count  14.0000    13.000000    14.000000     4.000000  14.000000
# mean    7.5000  7739.307692  2073.214286   550.000000  22.142857
# std     4.1833   103.714660  1182.503224   602.771377   8.017837
# min     1.0000  7566.000000   800.000000     0.000000  10.000000
# 25%     4.2500  7698.000000  1250.000000   225.000000  20.000000
# 50%     7.5000  7698.000000  1550.000000   400.000000  20.000000
# 75%    10.7500  7839.000000  2943.750000   725.000000  30.000000
# max    14.0000  7902.000000  5000.000000  1400.000000  30.000000

# %%
emp1 = pd.read_csv('d:\\data\\csv\\empcn.csv')

emp1.count()
# Out:
# empno       14
# ename       14
# job         14
# mgr         13
# hiredate    14
# sal         14
# comm         4
# deptno      14
# dtype: int64

# %%
emp.job.value_counts()
# Out:
# CLERK        4
# SALESMAN     4
# MANAGER      3
# ANALYST      2
# PRESIDENT    1
# Name: job, dtype: int64

# %%
titanic = pd.read_csv('d:\\data\\csv\\train.csv')
titanic.head()
titanic.Age.mean()
# Out:
# 29.69911764705882

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

km = pd.read_csv('d:\\data\\csv\\korea_move2.csv',header=None, encoding = 'cp949')
url2 = pd.read_html("d:\\data\\csv\\실습파일\\sample2.html")

dcnt = url2[5][2].str.split('+').str[1].str.split(')').str[0]
d = url2[5][1]
dcnt

r = pd.DataFrame({'date':d, 'cnt':dcnt})[2:-2]

k = km.T[6:]#csv파일에서 서식 변경으로 0월0일 형태로 바꿨습니다.
k.columns = ['date',1,2]

me = pd.merge(k,r, on = 'date')
me.set_index('date',inplace=True)

me[1]=pd.to_numeric(me[1])
me[2]=pd.to_numeric(me[2])

for i in range(len(me)):
    me['cnt'][i]=me['cnt'][i].replace(',','')
me['cnt']=pd.to_numeric(me['cnt'])

#print(me.corr())
me.corr()
k = me.plot(kind='line')
k.set_xticklabels(me.date, rotation=30)
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-30366a726c74> in <module>
#      28 me.corr()
#      29 k = me.plot(kind='line')
# ---> 30 k.set_xticklabels(me.date, rotation=30)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
km = pd.read_csv('d:\\data\\csv\\korea_move.csv',header=None, encoding = 'cp949')
k = km.T[6:]
tk = k[0].str.split('-')
#pd.to_numeric(tk.str[1]).apply(str)+"월 "+pd.to_numeric(tk.str[2]).apply(str)+'일'
k['date']=pd.to_numeric(tk.str[1]).apply(str)+"월 "+pd.to_numeric(tk.str[2]).apply(str)+'일'
k
# Out:
#               0       1       2    date
# 6    2020-01-13     100     100  1월 13일
# 7    2020-01-14   98.53  101.26  1월 14일
# 8    2020-01-15  101.94  104.37  1월 15일
# 9    2020-01-16  108.13  109.61  1월 16일
# 10   2020-01-17  122.17  128.68  1월 17일
# ..          ...     ...     ...     ...
# 182  2020-07-07   71.29   47.85   7월 7일
# 183  2020-07-08   72.19   47.82   7월 8일
# 184  2020-07-09   71.53    44.9   7월 9일
# 185  2020-07-10   96.12   71.88  7월 10일
# 186  2020-07-11   80.68   57.57  7월 11일
#
# [181 rows x 4 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


km = pd.read_csv('d:\\data\\csv\\korea_move.csv',header=None, encoding = 'cp949')
ml("d:\\data\\csv\\실습파일\\sample2.html")

dcnt = url2[5][2].str.split('+').str[1].str.split(')').str[0]
d = url2[5][1]
dcnt

r = pd.DataFrame({'date':d, 'cnt':dcnt})[2:-2]

k = km.T[6:]
tk = k[0].str.split('-')
#pd.to_numeric(tk.str[1]).apply(str)+"월 "+pd.to_numeric(tk.str[2]).apply(str)+'일'
k['date']=pd.to_numeric(tk.str[1]).apply(str)+"월 "+pd.to_numeric(tk.str[2]).apply(str)+'일'



me = pd.merge(k,r, on = 'date')
me.set_index('date',inplace=True)

me[1]=pd.to_numeric(me[1])
me[2]=pd.to_numeric(me[2])

for i in range(len(me)):
    me['cnt'][i]=me['cnt'][i].replace(',','')
me['cnt']=pd.to_numeric(me['cnt'])

#print(me.corr())
me.corr()
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             1         2       cnt
# 1    1.000000  0.833496 -0.449623
# 2    0.833496  1.000000 -0.325326
# cnt -0.449623 -0.325326  1.000000

# %%
sns.heatmap(me.corr(), annot = True, cmap= 'RdYlGn', linewidths = 0.2)
fig = plt.gcf()
plt.show()

# %%
km = pd.read_csv('d:\\data\\csv\\korea_move2.csv',header=None, encoding = 'cp949')
url2 = pd.read_html("d:\\data\\csv\\실습파일\\sample2.html")
dcnt = url2[5][2].str.split('+').str[1].str.split(')').str[0]
d = url2[5][1]
dcnt

r = pd.DataFrame({'date':d, 'cnt':dcnt})[2:-2]

k = km.T[6:]

pd.concat([r,k])
# Out:
#           0      1      2  cnt    date
# 2       NaN    NaN    NaN    1  1월 20일
# 3       NaN    NaN    NaN    1  1월 24일
# 4       NaN    NaN    NaN    1  1월 26일
# 5       NaN    NaN    NaN    1  1월 27일
# 6       NaN    NaN    NaN    1  1월 30일
# ..      ...    ...    ...  ...     ...
# 182   7월 7일  71.29  47.85  NaN     NaN
# 183   7월 8일  72.19  47.82  NaN     NaN
# 184   7월 9일  71.53   44.9  NaN     NaN
# 185  7월 10일  96.12  71.88  NaN     NaN
# 186  7월 11일  80.68  57.57  NaN     NaN
#
# [346 rows x 5 columns]

# %%
import pandas as pd
import seaborn as sns
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

sns.heatmap(titanic.corr(), annot = True, cmap= 'RdYlGn', linewidths = 0.2)
fig = plt.gcf()
fig.set_size_inches(10,8)
plt.show()
