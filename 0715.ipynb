# %%
import matplotlib.pyplot as plt
import seaborn as sns

tat = sns.load_dataset('titanic')

#스타일 설정하기
sns.set_style('darkgrid')

#히스토그램 그래프 그리기
#sns.distplot(tat['fare']) # 히스토그램 그래프 + 확률 밀도 함수 출력
sns.distplot(tat['fare'], hist=False) # 확률 밀도 함수만 출력
sns.distplot(tat['fare'], kde=False) # 히스토그램 그래프만 출력
#tat

# %%
import pandas as pd

insu = pd.read_csv('d:\\data\\csv\\insurance.csv')
insu
sns.distplot(insu['expenses'])

# %%
import numpy as np

h = np.random.randn(100000)*5 + 140
print(h[1])
cnt = 0
for i in h:
    if 150>=i >= 145 :
        cnt += 1
cnt/len(h)#
# Out:
# 137.70697884781944
# 0.13792

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

h = np.arange(140,160,0.001)
plt.plot(h, norm.pdf(h, 150, 5))
plt.show()

# %%
import pandas as pd

tat = pd.read_csv('d:\\data\\csv\\train.csv')
tat.Age.plot.hist()

# %%
tat.Age.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
pd.isnull(tat.Age).sum()
# Out:
# 0

# %%
am = int(tat.Age.mean())
am
# Out:
# 29

# %%
tat.Age.fillna(am, inplace=True)

# %%
tat.Age.plot.hist()

# %%
import pandas as pd

tat = pd.read_csv('d:\\data\\csv\\train.csv')

# %%
tat.Age.fillna(method = 'ffill', inplace=True)

# %%
tat.Age.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
tat.Age.plot.hist()

# %%
tat[tat.Age.isna()].shift(1).Age
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
#        ..
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: Age, Length: 177, dtype: float64

# %%
import seaborn as sns

flights = sns.load_dataset('flights')
flights.head()
df=flights.pivot('month','year','passengers')
df.head(20)
#sns.heatmap(df,cmap='YlGnBu', annot=True, fmt='d')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
df.style.background_gradient( cmap = 'spring')
# Out:
# <style  type="text/css" >
#     #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col0 {
#             background-color:  #ff2ed1;
#             color:  #f1f1f1;
#         }    #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col1 {
#             background-color:  #ff04fb;
#             color:  #f1f1f1;
#         }    #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col2 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col3 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col4 {
#             background-color:  #ff2cd3;
#             color:  #f1f1f1;
#         }    #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col5 {
#             background-color:  #ff23dc;
#             color:  #f1f1f1;
#         }    #T_63acd6ee_c648_11ea_8930_50b7c3a3f310row0_col6 {
#             background-color:  #ff11ee;
#             color:  #f1f1f1;
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tat = sns.load_dataset('titanic')
#df=flights.pivot('month','year','passengers')
tat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = tat.pivot_table(index=['sex'],columns=['class'],aggfunc = 'size')
sns.heatmap(df,cmap='YlGnBu', annot=True, fmt='d')

# %%
df.style.background_gradient( cmap = 'spring')
# Out:
# <style  type="text/css" >
#     #T_40234fa4_c649_11ea_857d_50b7c3a3f310row0_col0 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_40234fa4_c649_11ea_857d_50b7c3a3f310row0_col1 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_40234fa4_c649_11ea_857d_50b7c3a3f310row0_col2 {
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }    #T_40234fa4_c649_11ea_857d_50b7c3a3f310row1_col0 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_40234fa4_c649_11ea_857d_50b7c3a3f310row1_col1 {
#             background-color:  #ffff00;
#             color:  #000000;
#         }    #T_40234fa4_c649_11ea_857d_50b7c3a3f310row1_col2 {
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
tat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tat = sns.load_dataset('titanic')
sns.set_style('whitegrid')

sns.stripplot(x='class',y='age',data = tat)

# %%
tat = sns.load_dataset('titanic')
sns.set_style('whitegrid')

sns.swarmplot(x='class',y='age',data = tat)
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\knit\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
tat = sns.load_dataset('titanic')
sns.set_style('whitegrid')

sns.swarmplot(x='sex',y='age',data = tat)
# Out:
# C:\Users\knit\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\knit\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
tat = sns.load_dataset('titanic')
sns.set_style('whitegrid')

#sns.barplot(x='sex',y='survived',data = tat)
sns.barplot(x='sex',y='survived',hue = 'class',dodge= False,data = tat)

# %%
emp= pd.read_csv('d:\\data\\csv\\empcn.csv')
sns.set_style('whitegrid')

#sns.barplot(x='sex',y='survived',data = tat)
sns.barplot(x='deptno',y='sal',hue= 'job',data = emp)

# %%
tat = sns.load_dataset('titanic')
#sns.boxplot(x='alive',y='age',data=tat)
sns.boxplot(x='alive',y='age',hue='sex',data=tat)

# %%
sns.violinplot(x='alive',y='age',hue='sex',data=tat)

# %%
sns.countplot(x='class',hue='who',data=tat)

# %%
case = pd.read_csv('d:\\data\\csv\\corona\\Case.csv')
case
# Out:
#       case_id          province             city  group  \
# 0     1000001             Seoul       Yongsan-gu   True
# 1     1000002             Seoul        Gwanak-gu   True
# 2     1000003             Seoul          Guro-gu   True
# 3     1000004             Seoul     Yangcheon-gu   True
# 4     1000005             Seoul        Dobong-gu   True
# ..        ...               ...              ...    ...
# 169   6100012  Gyeongsangnam-do                -  False
# 170   7000001           Jeju-do                -  False
# 171   7000002           Jeju-do                -  False
# 172   7000003           Jeju-do                -  False
# 173   7000004           Jeju-do  from other city   True
#
#                   infection_case  confirmed   latitude   longitude
# 0                  Itaewon Clubs        139  37.538621  126.992652
# 1                        Richway        119   37.48208  126.901384
# 2            Guro-gu Call Center         95  37.508163  126.884387
# ...

# %%
case.group.value_counts()
# Out:
# True     124
# False     50
# Name: group, dtype: int64

# %%
sns.countplot(x='group',palette='Set3',hue='province',data=case)

# %%
sns.countplot(x='group',palette='Set3',hue='infection_case',data=case)

# %%
tat.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
fv =tat.embark_town.value_counts(dropna=False).idxmax()

# %%
tat.embark_town.fillna(fv, inplace = True)

# %%
tat.embark_town.value_counts(dropna=False)
# Out:
# Southampton    646
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
#1. 필요한 패키지를 import 한다. 
import  pandas  as  pd
import  seaborn  as  sns 

#1단계.  csv ---> 데이터 프레임으로 변환 
df = sns.load_dataset('titanic')

# 컬럼이 모두다 출력될 수 있도록 출력할 열의 개수 한도를 늘리기 
pd.set_option('display.max_columns', 15 ) 
print  (df.head()  )

print ( df.info()  ) 
print ( '\n' )  

print ( df.isnull().sum( axis=0)  )  
rdf =  df.drop(['deck', 'embark_town'] , axis= 1)
print ( rdf.columns.values )
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
# 나이의 누락 데이터의 행을 삭제하라
rdf = rdf.dropna( subset=['age'], how='any', axis= 0 )
print ( len(rdf)  ) 
print ('\n')

# 정박한 항구의 누락데이터 2건을 최빈값으로 채워라
most_freq = rdf['embarked'].value_counts(dropna=True).idxmax()
rdf['embarked'].fillna( most_freq, inplace=True ) 
print ( rdf.isnull().sum(axis=0)  ) 

ndf = rdf[ ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked']] 
print ( ndf.head()  )


gender = pd.get_dummies( ndf['sex'] )
ndf = pd.concat( [ndf, gender], axis=1 )
# Out:
# 714
#
#
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64
#    survived  pclass     sex   age  sibsp  parch embarked
# 0         0       3    male  22.0      1      0        S
# 1         1       1  female  38.0      1      0        C
# 2         1       3  female  26.0      0      0        S
# 3         1       1  female  35.0      1      0        S
# 4         0       3    male  35.0      0      0        S

# %%
onehot_embarked = pd.get_dummies( ndf['embarked'], prefix='town')
ndf = pd.concat([ ndf, onehot_embarked], axis=1)

ndf.drop( ['sex', 'embarked'],  axis=1, inplace=True )
print ( ndf.head() )
# Out:
#    survived  pclass   age  sibsp  parch  female  male  town_C  town_Q  town_S
# 0         0       3  22.0      1      0       0     1       0       0       1
# 1         1       1  38.0      1      0       1     0       1       0       0
# 2         1       3  26.0      0      0       1     0       0       0       1
# 3         1       1  35.0      1      0       1     0       0       0       1
# 4         0       3  35.0      0      0       0     1       0       0       1

# %%
X = ndf[ [ 'pclass' ,'age', 'sibsp','parch', 'female', 'male', 'town_C', 'town_Q',  'town_S']]
y = ndf['survived']   # 종속변수 

y.value_counts()
# Out:
# 0    424
# 1    290
# Name: survived, dtype: int64

# %%
#4.2  독립변수들을 정규화(normalization) 한다. #표준화?

from  sklearn   import   preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
print (X)

from  sklearn.model_selection  import   train_test_split
X_train, X_test, y_train, y_test =train_test_split( X, y, test_size=0.3, 
                                                           random_state = 10 ) 
                                                                    #ㄴ R에서 seed 값과 같음
# 설명:  test_size=0.3 에 의해서 7:3 비율로 훈련과 테스트를 나누고
# random_state=10 에 의해서 나중에 split 할 때도 항상 일정하게 
# split 할 수 있게 한다. 

print  ( 'train data 의 갯수:'  ,  X_train.shape )
print  ( 'test  data 의 갯수:'  ,  X_test.shape )
# Out:
# [[ 0.91123237 -0.53037664  0.52457013 ... -0.47180795 -0.20203051
#    0.53307848]
#  [-1.47636364  0.57183099  0.52457013 ...  2.11950647 -0.20203051
#   -1.87589641]
#  [ 0.91123237 -0.25482473 -0.55170307 ... -0.47180795 -0.20203051
#    0.53307848]
#  ...
#  [-1.47636364 -0.73704057 -0.55170307 ... -0.47180795 -0.20203051
#    0.53307848]
#  [-1.47636364 -0.25482473 -0.55170307 ...  2.11950647 -0.20203051
#   -1.87589641]
#  [ 0.91123237  0.15850313 -0.55170307 ... -0.47180795  4.94974747
#   -1.87589641]]
# train data 의 갯수: (499, 9)
# test  data 의 갯수: (215, 9)

# %%
from  sklearn.neighbors  import   KNeighborsClassifier 

knn = KNeighborsClassifier( n_neighbors=5 ) 
knn.fit ( X_train, y_train )
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
#예측
y_hat = knn.predict( X_test ) 

from  sklearn   import   metrics 
knn_matrix  =  metrics.confusion_matrix( y_test,  y_hat )
print ( knn_matrix )
# Out:
# [[109  16]
#  [ 25  65]]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score( y_test, y_hat)

print(accuracy)
# Out:
# 0.8093023255813954

# %%
#1. 필요한 패키지를 import 한다. 
import  pandas  as  pd
import  seaborn  as  sns 

#1단계.  csv ---> 데이터 프레임으로 변환 
df = sns.load_dataset('titanic')

# 컬럼이 모두다 출력될 수 있도록 출력할 열의 개수 한도를 늘리기 
pd.set_option('display.max_columns', 15 ) 
# print  (df.head()  )

# print ( df.info()  ) 
# print ( '\n' )  

# print ( df.isnull().sum( axis=0)  )  
rdf =  df.drop(['deck', 'embark_town'] , axis= 1)
# print ( rdf.columns.values ) 

# 나이의 누락 데이터의 행을 삭제하라
mage = rdf['age'].mean(axis = 0)
rdf['age'].fillna(mage,inplace=True)
#rdf = rdf.dropna( subset=['age'], how='any', axis= 0 )
# print ( len(rdf)  ) 
# print ('\n')

# 정박한 항구의 누락데이터 2건을 최빈값으로 채워라
most_freq = rdf['embarked'].value_counts(dropna=True).idxmax()
rdf['embarked'].fillna( most_freq, inplace=True ) 
# print ( rdf.isnull().sum(axis=0)  ) 


ndf = rdf[ ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked']] 
# print ( ndf.head()  )

# 명목형 더미변수 생성
gender = pd.get_dummies( ndf['sex'] )
ndf = pd.concat( [ndf, gender], axis=1 ) 

onehot_embarked = pd.get_dummies( ndf['embarked'], prefix='town')
ndf = pd.concat([ ndf, onehot_embarked], axis=1)
# 명목형 컬럼 2개 제거
ndf.drop( ['sex', 'embarked'],  axis=1, inplace=True )
# print ( ndf.head() ) 

#훈련할 학습데이터 x와 정답라벨 y 생성
X = ndf[ [ 'pclass' ,'age', 'sibsp','parch', 'female', 'male', 'town_C', 'town_Q',  'town_S']]
y = ndf['survived']   # 종속변수 

#4.2  독립변수들을 정규화(normalization) 한다. #표준화?

from  sklearn   import   preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
# print (X)

from  sklearn.model_selection  import   train_test_split
X_train, X_test, y_train, y_test =train_test_split( X, y, test_size=0.3, 
                                                           random_state = 10 ) 
                                                                    #ㄴ R에서 seed 값과 같음
# 설명:  test_size=0.3 에 의해서 7:3 비율로 훈련과 테스트를 나누고
# random_state=10 에 의해서 나중에 split 할 때도 항상 일정하게 
# split 할 수 있게 한다. 

print  ( 'train data 의 갯수:'  ,  X_train.shape )
print  ( 'test  data 의 갯수:'  ,  X_test.shape )

#knn머신러닝 모델로 학습 k=5
from  sklearn.neighbors  import   KNeighborsClassifier 

knn = KNeighborsClassifier( n_neighbors=5 ) 
knn.fit ( X_train, y_train )

# 사망자와 생존자를 예측
y_hat = knn.predict( X_test ) 

from  sklearn   import   metrics 
knn_matrix  =  metrics.confusion_matrix( y_test,  y_hat )
print ( knn_matrix ) 

# 모델의 정확도를 확인한다.
from sklearn.metrics import accuracy_score

accuracy = accuracy_score( y_test, y_hat)

print(accuracy)
# Out:
# train data 의 갯수: (623, 9)
# test  data 의 갯수: (268, 9)
# [[153  21]
#  [ 27  67]]
# 0.8208955223880597

# %%
#1. 필요한 패키지를 import 한다. 
import  pandas  as  pd
import  seaborn  as  sns 

#1단계.  csv ---> 데이터 프레임으로 변환 
df = sns.load_dataset('titanic')

# 컬럼이 모두다 출력될 수 있도록 출력할 열의 개수 한도를 늘리기 
pd.set_option('display.max_columns', 15 ) 
# print  (df.head()  )
df = df.drop_duplicates()
# print ( df.info()  ) 
# print ( '\n' )  

# print ( df.isnull().sum( axis=0)  )  
rdf =  df.drop(['deck', 'embark_town'] , axis= 1)
# print ( rdf.columns.values ) 

# 나이의 누락 데이터의 행을 삭제하라
fage = rdf['age'].value_counts(dropna=True).idxmax()
rdf['age'].fillna(fage,inplace=True)
#rdf = rdf.dropna( subset=['age'], how='any', axis= 0 )
# print ( len(rdf)  ) 
# print ('\n')

# 정박한 항구의 누락데이터 2건을 최빈값으로 채워라
most_freq = rdf['embarked'].value_counts(dropna=True).idxmax()
rdf['embarked'].fillna( most_freq, inplace=True ) 
# print ( rdf.isnull().sum(axis=0)  ) 


ndf = rdf[ ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked']] 
# print ( ndf.head()  )

# 명목형 더미변수 생성
gender = pd.get_dummies( ndf['sex'] )
ndf = pd.concat( [ndf, gender], axis=1 ) 

onehot_embarked = pd.get_dummies( ndf['embarked'], prefix='town')
ndf = pd.concat([ ndf, onehot_embarked], axis=1)
# 명목형 컬럼 2개 제거
ndf.drop( ['sex', 'embarked'],  axis=1, inplace=True )
# print ( ndf.head() ) 

#훈련할 학습데이터 x와 정답라벨 y 생성
X = ndf[ [ 'pclass' ,'age', 'sibsp','parch', 'female', 'male', 'town_C', 'town_Q',  'town_S']]
y = ndf['survived']   # 종속변수 

#4.2  독립변수들을 정규화(normalization) 한다. #표준화?

from  sklearn   import   preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
# print (X)

from  sklearn.model_selection  import   train_test_split
X_train, X_test, y_train, y_test =train_test_split( X, y, test_size=0.3, 
                                                           random_state = 10 ) 
                                                                    #ㄴ R에서 seed 값과 같음
# 설명:  test_size=0.3 에 의해서 7:3 비율로 훈련과 테스트를 나누고
# random_state=10 에 의해서 나중에 split 할 때도 항상 일정하게 
# split 할 수 있게 한다. 

print  ( 'train data 의 갯수:'  ,  X_train.shape )
print  ( 'test  data 의 갯수:'  ,  X_test.shape )

#knn머신러닝 모델로 학습 k=5
from  sklearn.neighbors  import   KNeighborsClassifier 

knn = KNeighborsClassifier( n_neighbors=5 ) 
knn.fit ( X_train, y_train )

# 사망자와 생존자를 예측
y_hat = knn.predict( X_test ) 

from  sklearn   import   metrics 
knn_matrix  =  metrics.confusion_matrix( y_test,  y_hat )
print ( knn_matrix ) 

# 모델의 정확도를 확인한다.
from sklearn.metrics import accuracy_score

accuracy = accuracy_score( y_test, y_hat)

print(accuracy)
# Out:
# train data 의 갯수: (548, 9)
# test  data 의 갯수: (236, 9)
# [[113  19]
#  [ 40  64]]
# 0.75

# %%
#1. 필요한 패키지를 import 한다. 
import  pandas  as  pd
import  seaborn  as  sns 

#1단계.  csv ---> 데이터 프레임으로 변환 
df = sns.load_dataset('titanic')

# 컬럼이 모두다 출력될 수 있도록 출력할 열의 개수 한도를 늘리기 
pd.set_option('display.max_columns', 15 ) 
# print  (df.head()  )

# print ( df.info()  ) 
# print ( '\n' )  

# print ( df.isnull().sum( axis=0)  )  
rdf =  df.drop(['deck', 'embark_town'] , axis= 1)
# print ( rdf.columns.values ) 

# 나이의 누락 데이터의 행을 삭제하라
#mage = rdf['age'].mean(axis = 0)
rdf['age'].fillna(method='ffill',inplace=True)
#rdf = rdf.dropna( subset=['age'], how='any', axis= 0 )
# print ( len(rdf)  ) 
# print ('\n')

# 정박한 항구의 누락데이터 2건을 최빈값으로 채워라
most_freq = rdf['embarked'].value_counts(dropna=True).idxmax()
rdf['embarked'].fillna( most_freq, inplace=True ) 
# print ( rdf.isnull().sum(axis=0)  ) 


ndf = rdf[ ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'embarked']] 
# print ( ndf.head()  )

# 명목형 더미변수 생성
gender = pd.get_dummies( ndf['sex'] )
ndf = pd.concat( [ndf, gender], axis=1 ) 

onehot_embarked = pd.get_dummies( ndf['embarked'], prefix='town')
ndf = pd.concat([ ndf, onehot_embarked], axis=1)
# 명목형 컬럼 2개 제거
ndf.drop( ['sex', 'embarked'],  axis=1, inplace=True )
# print ( ndf.head() ) 

#훈련할 학습데이터 x와 정답라벨 y 생성
X = ndf[ [ 'pclass' ,'age', 'sibsp','parch', 'female', 'male', 'town_C', 'town_Q',  'town_S']]
y = ndf['survived']   # 종속변수 

#4.2  독립변수들을 정규화(normalization) 한다. #표준화?

from  sklearn   import   preprocessing
X = preprocessing.StandardScaler().fit(X).transform(X)
# print (X)

from  sklearn.model_selection  import   train_test_split
X_train, X_test, y_train, y_test =train_test_split( X, y, test_size=0.3, 
                                                           random_state = 10 ) 
                                                                    #ㄴ R에서 seed 값과 같음
# 설명:  test_size=0.3 에 의해서 7:3 비율로 훈련과 테스트를 나누고
# random_state=10 에 의해서 나중에 split 할 때도 항상 일정하게 
# split 할 수 있게 한다. 

print  ( 'train data 의 갯수:'  ,  X_train.shape )
print  ( 'test  data 의 갯수:'  ,  X_test.shape )

#knn머신러닝 모델로 학습 k=5
from  sklearn.neighbors  import   KNeighborsClassifier 

knn = KNeighborsClassifier( n_neighbors=5 ) 
knn.fit ( X_train, y_train )

# 사망자와 생존자를 예측
y_hat = knn.predict( X_test ) 

from  sklearn   import   metrics 
knn_matrix  =  metrics.confusion_matrix( y_test,  y_hat )
print ( knn_matrix ) 

# 모델의 정확도를 확인한다.
from sklearn.metrics import accuracy_score

accuracy = accuracy_score( y_test, y_hat)

print(accuracy)
# Out:
# train data 의 갯수: (623, 9)
# test  data 의 갯수: (268, 9)
# [[152  22]
#  [ 26  68]]
# 0.8208955223880597
